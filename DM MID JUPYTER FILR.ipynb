# %%
import itertools
import pandas as pd
import time

def load_transactions_from_csv(file_path):
    df = pd.read_csv(file_path, header=None, skiprows=1)
    transactions = df[1].apply(lambda x: set(x.split(' , '))).tolist()
    return transactions
start_time = time.time()
def find_frequent_itemsets_bruteforce(transactions, min_support, max_k=3):
    unique_items = set(item for transaction in transactions for item in transaction)
    frequent_itemsets = []
    for k in range(1, max_k + 1):
        candidate_itemsets = generate_itemsets(unique_items, k)
        for itemset in candidate_itemsets:
            support = sum(1 for transaction in transactions if set(itemset).issubset(transaction))
            if support >= min_support:
                frequent_itemsets.append((set(itemset), support))
    return frequent_itemsets

def generate_itemsets(items, length):
    return list(itertools.combinations(items, length))

def generate_association_rules(frequent_itemsets, transactions, min_confidence):
    rules = []
    for itemset, support in frequent_itemsets:
        for i in range(1, len(itemset)):
            for antecedent in itertools.combinations(itemset, i):
                antecedent = set(antecedent)
                consequent = itemset - antecedent
                antecedent_support = sum(1 for transaction in transactions if antecedent.issubset(transaction))
                if antecedent_support > 0:
                    confidence = support / antecedent_support
                    if confidence >= min_confidence:
                        rules.append((antecedent, consequent, confidence))
    return rules

def process_dataset(file_path, min_support, min_confidence):
    transactions = load_transactions_from_csv(file_path)
    frequent_itemsets = find_frequent_itemsets_bruteforce(transactions, min_support)
    association_rules = generate_association_rules(frequent_itemsets, transactions, min_confidence)
    return frequent_itemsets, association_rules


file_paths = [
    r'C:\Users\Rushmitha K\Downloads\amazon_data.csv',
r'C:\Users\Rushmitha K\Downloads\costco_data.csv',
r'C:\Users\Rushmitha K\Downloads\best_buy_data.csv',
r'C:\Users\Rushmitha K\Downloads\walgreens_data.csv',
r'C:\Users\Rushmitha K\Downloads\walmart_data.csv'
]


min_support = 2
min_confidence = 0.5


for file_path in file_paths:
    frequent_itemsets, association_rules = process_dataset(file_path, min_support, min_confidence)
    print(f"Results for {file_path}:")
    print("Frequent Itemsets:", frequent_itemsets)
    print("Association Rules:", association_rules)
    print("\n")

brute_time = start_time - time.time()
print("Time taken: " )
print(brute_time * -1)
# Out:
# Results for C:\Users\Rushmitha K\Downloads\amazon_data.csv:
# Frequent Itemsets: [({'Cheese'}, 44), ({'Sugar, Diapers, Cheese, Sugar, Sugar'}, 4), ({'Sugar, Diapers, Cheese, Sugar'}, 49), ({'Diapers, Diapers, Diapers'}, 5), ({'Detergent, Shampoo, Shampoo, Shampoo'}, 2), ({'Detergent, Shampoo, Shampoo'}, 40), ({'Diapers, Flour, Cheese, Diapers, Cheese'}, 2), ({'Shampoo, Detergent, Detergent'}, 42), ({'Flour, Cheese, Flour, Flour'}, 2), ({'Detergent, Shampoo, Shampoo, Detergent'}, 2), ({'Diapers, Diapers'}, 55), ({'Flour, Cheese, Flour'}, 56), ({'Detergent, Cheese, Sugar, Cheese'}, 51), ({'Juice, Tea, Juice, Tea'}, 2), ({'Diapers, Flour, Cheese, Diapers, Flour'}, 2), ({'Detergent, Cheese, Sugar, Cheese, Detergent'}, 3), ({'Detergent, Shampoo, Tea, Cheese, Shampoo, Shampoo'}, 3), ({'Cheese, Cheese, Cheese'}, 7), ({'Sugar, Sugar'}, 53), ({'Diapers, Flour, Cheese, Diapers, Diapers'}, 3), ({'Tea'}, 101), ({'Detergent, Tea'}, 42), ({'Detergent, Shampoo, Tea, Cheese, Shampoo'}, 43), ({'Flour, Juice, Juice'}, 64), ({'Juice, Tea, Juice, Juice'}, 3), ({'Sugar, Sugar, Sugar'}, 6), ({'Juice, Tea, Juice'}, 44), ({'Cheese, Cheese'}, 116), ({'Shampoo, Detergent, Detergent, Shampoo'}, 2), ({'Flour, Cheese, Flour, Cheese'}, 2), ({'Sugar, Diapers, Cheese, Sugar, Diapers'}, 2), ({'Tea, Tea'}, 3), ({'Detergent, Cheese, Sugar, Cheese, Cheese'}, 3), ({'Detergent, Tea, Detergent'}, 3), ({'Diapers, Flour, Cheese, Diapers'}, 48)]
# Association Rules: []
#
#
# Results for C:\Users\Rushmitha K\Downloads\costco_data.csv:
# Frequent Itemsets: [({' Bulk Vegetables'}, 162), ({' Garden Supplies,  Bulk Vegetables '}, 52), ({' Tires'}, 145), ({' Tires,  Tires'}, 31), ({' Cleaning Supplies,  Cleaning Supplies,  Cleaning Supplies'}, 4), ({' Bulk Fruits '}, 155), ({' Optical Items'}, 106), ({' Bulk Fruits'}, 104), ({'Jewelry,  Jewelry'}, 45), ({' Garden Supplies '}, 88), ({' Cleaning Supplies,  Cleaning Supplies'}, 102), ({' Bulk Vegetables,  Jewelry '}, 2), ({'Bakery Items'}, 208), ({'Cleaning Supplies'}, 47), ({'Optical Items,  Optical Items,  Optical Items'}, 2), ({' Bulk Vegetables,  Bulk Vegetables'}, 2), ({' Jewelry,  Tires '}, 39), ({'Optical Items,  Optical Items'}, 42), ({' Garden Supplies'}, 148), ({' Bakery Items'}, 67), ({' Jewelry'}, 49), ({' Garden Supplies,  Bulk Vegetables'}, 3), ({' Bulk Vegetables '}, 2), ({' Bulk Fruits,  Bulk Fruits'}, 45), ({' Tires '}, 7), ({' Optical Items,  Optical Items,  Bakery Items '}, 2), ({' Optical Items,  Optical Items'}, 101), ({'Garden Supplies'}, 45), ({' Optical Items,  Optical Items,  Optical Items'}, 9), ({' Jewelry,  Tires'}, 6), ({'Jewelry'}, 64), ({'Bulk Fruits'}, 98), ({' Bulk Vegetables', ' Garden Supplies,  Bulk Vegetables '}, 52), ({' Bulk Vegetables', ' Tires'}, 55), ({' Bulk Vegetables', ' Garden Supplies '}, 47), ({' Bulk Vegetables', 'Cleaning Supplies'}, 47), ({' Bulk Vegetables', ' Garden Supplies'}, 48), ({' Garden Supplies,  Bulk Vegetables', ' Bulk Vegetables'}, 3), ({' Bulk Vegetables', ' Bulk Vegetables '}, 2), ({' Bulk Vegetables', 'Jewelry'}, 60), ({' Garden Supplies,  Bulk Vegetables ', ' Tires'}, 52), ({' Garden Supplies ', ' Tires'}, 41), ({' Jewelry,  Tires ', ' Tires'}, 39), ({' Tires', ' Garden Supplies'}, 6), ({' Jewelry', ' Tires'}, 2), ({' Garden Supplies,  Bulk Vegetables', ' Tires'}, 3), ({' Tires', ' Bulk Vegetables '}, 2), ({' Tires ', ' Tires'}, 7), ({'Garden Supplies', ' Tires'}, 45), ({' Tires', ' Jewelry,  Tires'}, 6), ({'Bulk Fruits', ' Tires'}, 45), ({' Optical Items', ' Cleaning Supplies,  Cleaning Supplies,  Cleaning Supplies'}, 2), ({'Bakery Items', ' Cleaning Supplies,  Cleaning Supplies,  Cleaning Supplies'}, 2), ({' Optical Items', ' Bulk Fruits '}, 50), ({' Bulk Fruits', ' Bulk Fruits '}, 55), ({'Bakery Items', ' Bulk Fruits '}, 51), ({'Bulk Fruits', ' Bulk Fruits '}, 54), ({' Optical Items', ' Bulk Fruits'}, 51), ({' Optical Items', ' Cleaning Supplies,  Cleaning Supplies'}, 53), ({' Optical Items', 'Bakery Items'}, 55), ({' Bulk Fruits', ' Jewelry'}, 47), ({' Bulk Fruits', ' Optical Items,  Optical Items'}, 42), ({' Bulk Fruits', ' Optical Items,  Optical Items,  Optical Items'}, 3), ({' Bulk Fruits', 'Bulk Fruits'}, 5), ({'Cleaning Supplies', ' Garden Supplies '}, 47), ({' Garden Supplies ', ' Garden Supplies'}, 48), ({'Garden Supplies', ' Garden Supplies '}, 41), ({'Bakery Items', ' Cleaning Supplies,  Cleaning Supplies'}, 53), ({' Bulk Vegetables,  Jewelry ', 'Jewelry'}, 2), ({'Bakery Items', ' Garden Supplies'}, 54), ({'Bakery Items', ' Bulk Fruits,  Bulk Fruits'}, 45), ({'Cleaning Supplies', ' Garden Supplies'}, 47), ({' Bulk Vegetables,  Bulk Vegetables', 'Jewelry'}, 2), ({' Jewelry,  Tires ', 'Bulk Fruits'}, 39), ({' Tires ', ' Garden Supplies'}, 4), ({'Garden Supplies', ' Garden Supplies'}, 5), ({' Bakery Items', ' Optical Items,  Optical Items,  Bakery Items '}, 2), ({' Bakery Items', ' Optical Items,  Optical Items'}, 59), ({' Bakery Items', ' Optical Items,  Optical Items,  Optical Items'}, 6), ({' Jewelry', ' Optical Items,  Optical Items'}, 42), ({' Jewelry', ' Optical Items,  Optical Items,  Optical Items'}, 3), ({' Jewelry', ' Jewelry,  Tires'}, 2), ({' Jewelry', 'Bulk Fruits'}, 2), ({' Garden Supplies,  Bulk Vegetables', ' Bulk Vegetables '}, 2), ({' Tires ', 'Garden Supplies'}, 4), ({' Tires ', ' Jewelry,  Tires'}, 3), ({' Tires ', 'Bulk Fruits'}, 3), ({'Bulk Fruits', ' Jewelry,  Tires'}, 6), ({' Bulk Vegetables', ' Garden Supplies,  Bulk Vegetables ', ' Tires'}, 52), ({' Garden Supplies,  Bulk Vegetables', ' Bulk Vegetables', ' Tires'} ...
# Association Rules: [({' Garden Supplies,  Bulk Vegetables '}, {' Bulk Vegetables'}, 1.0), ({' Garden Supplies '}, {' Bulk Vegetables'}, 0.5340909090909091), ({'Cleaning Supplies'}, {' Bulk Vegetables'}, 1.0), ({' Garden Supplies,  Bulk Vegetables'}, {' Bulk Vegetables'}, 1.0), ({' Bulk Vegetables '}, {' Bulk Vegetables'}, 1.0), ({'Jewelry'}, {' Bulk Vegetables'}, 0.9375), ({' Garden Supplies,  Bulk Vegetables '}, {' Tires'}, 1.0), ({' Jewelry,  Tires '}, {' Tires'}, 1.0), ({' Garden Supplies,  Bulk Vegetables'}, {' Tires'}, 1.0), ({' Bulk Vegetables '}, {' Tires'}, 1.0), ({' Tires '}, {' Tires'}, 1.0), ({'Garden Supplies'}, {' Tires'}, 1.0), ({' Jewelry,  Tires'}, {' Tires'}, 1.0), ({' Cleaning Supplies,  Cleaning Supplies,  Cleaning Supplies'}, {' Optical Items'}, 0.5), ({' Cleaning Supplies,  Cleaning Supplies,  Cleaning Supplies'}, {'Bakery Items'}, 0.5), ({' Bulk Fruits'}, {' Bulk Fruits '}, 0.5288461538461539), ({'Bulk Fruits'}, {' Bulk Fruits '}, 0.5510204081632653), ({' Optical Items'}, {' Cleaning Supplies,  Cleaning Supplies'}, 0.5), ({' Cleaning Supplies,  Cleaning Supplies'}, {' Optical Items'}, 0.5196078431372549), ({' Optical Items'}, {'Bakery Items'}, 0.5188679245283019), ({' Jewelry'}, {' Bulk Fruits'}, 0.9591836734693877), ({'Cleaning Supplies'}, {' Garden Supplies '}, 1.0), ({' Garden Supplies '}, {'Cleaning Supplies'}, 0.5340909090909091), ({' Garden Supplies '}, {' Garden Supplies'}, 0.5454545454545454), ({'Garden Supplies'}, {' Garden Supplies '}, 0.9111111111111111), ({' Cleaning Supplies,  Cleaning Supplies'}, {'Bakery Items'}, 0.5196078431372549), ({' Bulk Vegetables,  Jewelry '}, {'Jewelry'}, 1.0), ({' Bulk Fruits,  Bulk Fruits'}, {'Bakery Items'}, 1.0), ({'Cleaning Supplies'}, {' Garden Supplies'}, 1.0), ({' Bulk Vegetables,  Bulk Vegetables'}, {'Jewelry'}, 1.0), ({' Jewelry,  Tires '}, {'Bulk Fruits'}, 1.0), ({' Tires '}, {' Garden Supplies'}, 0.5714285714285714), ({' Optical Items,  Optical Items,  Bakery Items '}, {' Bakery Items'}, 1.0), ({' Bakery Items'}, {' Optical Items,  Optical Items'}, 0.8805970149253731), ({' Optical Items,  Optical Items'}, {' Bakery Items'}, 0.5841584158415841), ({' Optical Items,  Optical Items,  Optical Items'}, {' Bakery Items'}, 0.6666666666666666), ({' Jewelry'}, {' Optical Items,  Optical Items'}, 0.8571428571428571), ({' Garden Supplies,  Bulk Vegetables'}, {' Bulk Vegetables '}, 0.6666666666666666), ({' Bulk Vegetables '}, {' Garden Supplies,  Bulk Vegetables'}, 1.0), ({' Tires '}, {'Garden Supplies'}, 0.5714285714285714), ({' Jewelry,  Tires'}, {' Tires '}, 0.5), ({' Jewelry,  Tires'}, {'Bulk Fruits'}, 1.0), ({' Garden Supplies,  Bulk Vegetables '}, {' Bulk Vegetables', ' Tires'}, 1.0), ({' Bulk Vegetables', ' Garden Supplies,  Bulk Vegetables '}, {' Tires'}, 1.0), ({' Bulk Vegetables', ' Tires'}, {' Garden Supplies,  Bulk Vegetables '}, 0.9454545454545454), ({' Garden Supplies,  Bulk Vegetables ', ' Tires'}, {' Bulk Vegetables'}, 1.0), ({' Garden Supplies,  Bulk Vegetables'}, {' Bulk Vegetables', ' Tires'}, 1.0), ({' Garden Supplies,  Bulk Vegetables', ' Bulk Vegetables'}, {' Tires'}, 1.0), ({' Garden Supplies,  Bulk Vegetables', ' Tires'}, {' Bulk Vegetables'}, 1.0), ({' Bulk Vegetables '}, {' Bulk Vegetables', ' Tires'}, 1.0), ({' Bulk Vegetables', ' Bulk Vegetables '}, {' Tires'}, 1.0), ({' Tires', ' Bulk Vegetables '}, {' Bulk Vegetables'}, 1.0), ({'Cleaning Supplies'}, {' Bulk Vegetables', ' Garden Supplies '}, 1.0), ({' Garden Supplies '}, {' Bulk Vegetables', 'Cleaning Supplies'}, 0.5340909090909091), ({' Bulk Vegetables', 'Cleaning Supplies'}, {' Garden Supplies '}, 1.0), ({' Bulk Vegetables', ' Garden Supplies '}, {'Cleaning Supplies'}, 1.0), ({'Cleaning Supplies', ' Garden Supplies '}, {' Bulk Vegetables'}, 1.0), ({' Garden Supplies '}, {' Bulk Vegetables', ' Garden Supplies'}, 0.5340909090909091), ({' Bulk Vegetables', ' Garden Supplies '}, {' Garden Supplies'}, 1.0), ({' Bulk Vegetables', ' Garden Supplies'}, {' Garden Supplies '}, 0.9791666666666666 ...
#
#
# Results for C:\Users\Rushmitha K\Downloads\best_buy_data.csv:
# Frequent Itemsets: [({' Smartphone'}, 2), ({'Keyboard,  Keyboard,  Keyboard'}, 9), ({' Keyboard,  Keyboard'}, 39), ({'Smartphone,  Smartphone'}, 51), ({' Speakers'}, 63), ({'External Hard Drive,  External Hard Drive,  External Hard Drive'}, 10), ({'Speakers'}, 104), ({' Smartwatch,  Smartwatch,  Smartwatch'}, 4), ({'Keyboard'}, 98), ({'Router'}, 107), ({' Smartwatch,  Smartwatch,  Router '}, 2), ({' Printer,  Printer,  Speakers '}, 3), ({' Smartwatch '}, 2), ({' External Hard Drive '}, 2), ({'Smartphone,  Smartphone,  Smartphone'}, 4), ({' Router'}, 164), ({' Printer '}, 55), ({' Keyboard'}, 4), ({'External Hard Drive,  External Hard Drive'}, 37), ({' Router '}, 50), ({' Charger'}, 135), ({' External Hard Drive'}, 101), ({'Keyboard,  Keyboard'}, 92), ({' Smartphone '}, 48), ({' Smartwatch'}, 43), ({' Keyboard,  Keyboard,  Smartwatch '}, 2), ({' Printer,  Printer,  Printer'}, 4), ({'Smartphone'}, 48), ({'Smartwatch,  Smartwatch'}, 49), ({'External Hard Drive'}, 45), ({' Smartwatch,  Smartwatch'}, 54), ({' Printer'}, 151), ({' Speakers '}, 52), ({' Keyboard '}, 46), ({' Charger '}, 90), ({' Charger,  Charger'}, 48), ({'Smartwatch,  Smartwatch,  Smartwatch'}, 2), ({'Smartwatch'}, 102), ({' Printer,  Printer'}, 55), ({' Charger,  Charger,  Keyboard '}, 2), ({' Smartphone', ' Smartphone '}, 2), ({' Smartphone', 'Smartphone'}, 2), ({' External Hard Drive', ' Keyboard,  Keyboard'}, 39), ({' Keyboard,  Keyboard', ' Smartwatch'}, 39), ({' Printer', ' Keyboard,  Keyboard'}, 39), ({'Router', ' Speakers'}, 62), ({' Printer,  Printer,  Speakers ', ' Speakers'}, 3), ({' Speakers', ' Printer,  Printer,  Printer'}, 4), ({' Printer,  Printer', ' Speakers'}, 55), ({' External Hard Drive ', 'Speakers'}, 2), ({'Speakers', ' Printer '}, 54), ({' Charger', 'Speakers'}, 46), ({' External Hard Drive', 'Speakers'}, 58), ({' Printer', 'Speakers'}, 58), ({' Speakers ', 'Speakers'}, 3), ({' Charger ', 'Speakers'}, 45), ({' Router', ' Smartwatch,  Smartwatch,  Smartwatch'}, 4), ({' Router', 'Keyboard'}, 52), ({'Keyboard', ' Keyboard'}, 4), ({' Keyboard ', 'Keyboard'}, 46), ({' Charger,  Charger', 'Keyboard'}, 48), ({'Keyboard', ' Charger,  Charger,  Keyboard '}, 2), ({' Printer,  Printer,  Speakers ', 'Router'}, 3), ({'Router', ' Charger'}, 45), ({'Router', ' Printer,  Printer,  Printer'}, 4), ({' Charger ', 'Router'}, 45), ({'Router', ' Printer,  Printer'}, 55), ({' Router', ' Smartwatch,  Smartwatch,  Router '}, 2), ({' Smartwatch ', ' Router'}, 2), ({' Smartwatch ', 'Smartwatch'}, 2), ({' External Hard Drive ', ' External Hard Drive'}, 2), ({' External Hard Drive ', ' Printer'}, 2), ({' Router ', ' Router'}, 50), ({' Router', ' Smartwatch,  Smartwatch'}, 54), ({' Router', ' Charger,  Charger'}, 48), ({' Router', 'Smartwatch'}, 52), ({' Router', ' Charger,  Charger,  Keyboard '}, 2), ({' External Hard Drive', ' Printer '}, 54), ({' Printer', ' Printer '}, 55), ({' Keyboard ', ' Keyboard'}, 4), ({' Router ', 'Smartwatch'}, 50), ({' Charger', 'External Hard Drive'}, 44), ({' Charger ', ' Charger'}, 90), ({' External Hard Drive', ' Smartwatch'}, 43), ({' External Hard Drive', ' Keyboard,  Keyboard,  Smartwatch '}, 2), ({' Printer', ' External Hard Drive'}, 101), ({' Speakers ', ' External Hard Drive'}, 2), ({' Smartphone ', 'Smartphone'}, 48), ({' Keyboard,  Keyboard,  Smartwatch ', ' Smartwatch'}, 2), ({' Printer', ' Smartwatch'}, 43), ({' Printer', ' Keyboard,  Keyboard,  Smartwatch '}, 2), ({' Printer', ' Speakers '}, 51), ({'Smartwatch', ' Printer'}, 50), ({'Smartwatch', ' Speakers '}, 49), ({' Smartphone', ' Smartphone ', 'Smartphone'}, 2), ({' External Hard Drive', ' Keyboard,  Keyboard', ' Smartwatch'}, 39), ({' Printer', ' External Hard Drive', ' Keyboard,  Keyboard'}, 39), ({' Printer', ' Keyboard,  Keyboard', ' Smartwatch'}, 39), ({' Printer,  Printer,  Speakers ', 'Router', ' Speakers'}, 3), ({'Router', ' Speakers', ' Printer,  Printer,  Printer'}, 4), ({'Router', ' Speakers', ' Printer,  Printer'}, 55), ({' External Hard Drive ', ' External Har ...
# Association Rules: [({' Smartphone'}, {' Smartphone '}, 1.0), ({' Smartphone'}, {'Smartphone'}, 1.0), ({' Keyboard,  Keyboard'}, {' External Hard Drive'}, 1.0), ({' Keyboard,  Keyboard'}, {' Smartwatch'}, 1.0), ({' Smartwatch'}, {' Keyboard,  Keyboard'}, 0.9069767441860465), ({' Keyboard,  Keyboard'}, {' Printer'}, 1.0), ({'Router'}, {' Speakers'}, 0.5794392523364486), ({' Speakers'}, {'Router'}, 0.9841269841269841), ({' Printer,  Printer,  Speakers '}, {' Speakers'}, 1.0), ({' Printer,  Printer,  Printer'}, {' Speakers'}, 1.0), ({' Printer,  Printer'}, {' Speakers'}, 1.0), ({' Speakers'}, {' Printer,  Printer'}, 0.873015873015873), ({' External Hard Drive '}, {'Speakers'}, 1.0), ({'Speakers'}, {' Printer '}, 0.5192307692307693), ({' Printer '}, {'Speakers'}, 0.9818181818181818), ({' External Hard Drive'}, {'Speakers'}, 0.5742574257425742), ({'Speakers'}, {' External Hard Drive'}, 0.5576923076923077), ({'Speakers'}, {' Printer'}, 0.5576923076923077), ({' Charger '}, {'Speakers'}, 0.5), ({' Smartwatch,  Smartwatch,  Smartwatch'}, {' Router'}, 1.0), ({'Keyboard'}, {' Router'}, 0.5306122448979592), ({' Keyboard'}, {'Keyboard'}, 1.0), ({' Keyboard '}, {'Keyboard'}, 1.0), ({' Charger,  Charger'}, {'Keyboard'}, 1.0), ({' Charger,  Charger,  Keyboard '}, {'Keyboard'}, 1.0), ({' Printer,  Printer,  Speakers '}, {'Router'}, 1.0), ({' Printer,  Printer,  Printer'}, {'Router'}, 1.0), ({' Charger '}, {'Router'}, 0.5), ({'Router'}, {' Printer,  Printer'}, 0.514018691588785), ({' Printer,  Printer'}, {'Router'}, 1.0), ({' Smartwatch,  Smartwatch,  Router '}, {' Router'}, 1.0), ({' Smartwatch '}, {' Router'}, 1.0), ({' Smartwatch '}, {'Smartwatch'}, 1.0), ({' External Hard Drive '}, {' External Hard Drive'}, 1.0), ({' External Hard Drive '}, {' Printer'}, 1.0), ({' Router '}, {' Router'}, 1.0), ({' Smartwatch,  Smartwatch'}, {' Router'}, 1.0), ({' Charger,  Charger'}, {' Router'}, 1.0), ({'Smartwatch'}, {' Router'}, 0.5098039215686274), ({' Charger,  Charger,  Keyboard '}, {' Router'}, 1.0), ({' External Hard Drive'}, {' Printer '}, 0.5346534653465347), ({' Printer '}, {' External Hard Drive'}, 0.9818181818181818), ({' Printer '}, {' Printer'}, 1.0), ({' Keyboard'}, {' Keyboard '}, 1.0), ({' Router '}, {'Smartwatch'}, 1.0), ({'External Hard Drive'}, {' Charger'}, 0.9777777777777777), ({' Charger '}, {' Charger'}, 1.0), ({' Charger'}, {' Charger '}, 0.6666666666666666), ({' Smartwatch'}, {' External Hard Drive'}, 1.0), ({' Keyboard,  Keyboard,  Smartwatch '}, {' External Hard Drive'}, 1.0), ({' Printer'}, {' External Hard Drive'}, 0.6688741721854304), ({' External Hard Drive'}, {' Printer'}, 1.0), ({' Smartphone '}, {'Smartphone'}, 1.0), ({'Smartphone'}, {' Smartphone '}, 1.0), ({' Keyboard,  Keyboard,  Smartwatch '}, {' Smartwatch'}, 1.0), ({' Smartwatch'}, {' Printer'}, 1.0), ({' Keyboard,  Keyboard,  Smartwatch '}, {' Printer'}, 1.0), ({' Speakers '}, {' Printer'}, 0.9807692307692307), ({' Speakers '}, {'Smartwatch'}, 0.9423076923076923), ({' Smartphone'}, {' Smartphone ', 'Smartphone'}, 1.0), ({' Smartphone', ' Smartphone '}, {'Smartphone'}, 1.0), ({' Smartphone', 'Smartphone'}, {' Smartphone '}, 1.0), ({' Keyboard,  Keyboard'}, {' External Hard Drive', ' Smartwatch'}, 1.0), ({' Smartwatch'}, {' External Hard Drive', ' Keyboard,  Keyboard'}, 0.9069767441860465), ({' External Hard Drive', ' Keyboard,  Keyboard'}, {' Smartwatch'}, 1.0), ({' External Hard Drive', ' Smartwatch'}, {' Keyboard,  Keyboard'}, 0.9069767441860465), ({' Keyboard,  Keyboard', ' Smartwatch'}, {' External Hard Drive'}, 1.0), ({' Keyboard,  Keyboard'}, {' Printer', ' External Hard Drive'}, 1.0), ({' Printer', ' Keyboard,  Keyboard'}, {' External Hard Drive'}, 1.0), ({' External Hard Drive', ' Keyboard,  Keyboard'}, {' Printer'}, 1.0), ({' Keyboard,  Keyboard'}, {' Printer', ' Smartwatch'}, 1.0), ({' Smartwatch'}, {' Printer', ' Keyboard,  Keyboard'}, 0.9069767441860465), ({' Printer', ' Keyboard,  Keyboard'}, {' Smartwatch'}, 1.0), ({' Printer', ' Smartwatch'}, {' Keybo ...
#
#
# Results for C:\Users\Rushmitha K\Downloads\walgreens_data.csv:
# Frequent Itemsets: [({'Cold and Flu Medicine'}, 159), ({' Thermometer,  Blood Pressure Monitor '}, 47), ({' Insect Repellent '}, 53), ({' Eye Drops'}, 13), ({' Eye Drops '}, 138), ({'Toothpaste'}, 51), ({'Insect Repellent'}, 43), ({' First Aid Supplies '}, 46), ({' Band-Aids '}, 3), ({' Thermometer '}, 2), ({' Thermometer,  Thermometer'}, 86), ({' First Aid Supplies,  First Aid Supplies'}, 49), ({' Blood Pressure Monitor '}, 4), ({' Blood Pressure Monitor,  Band-Aids '}, 47), ({'Blood Pressure Monitor'}, 51), ({' Thermometer,  Insect Repellent '}, 2), ({' Blood Pressure Monitor,  Cold and Flu Medicine '}, 56), ({' Cold and Flu Medicine'}, 50), ({' Band-Aids,  Toothpaste'}, 4), ({' Blood Pressure Monitor,  Blood Pressure Monitor'}, 45), ({'Blood Pressure Monitor '}, 50), ({' Cold and Flu Medicine '}, 2), ({' First Aid Supplies,  Insect Repellent '}, 58), ({' Toothpaste,  Toothpaste'}, 38), ({' Blood Pressure Monitor,  Band-Aids'}, 3), ({' First Aid Supplies,  First Aid Supplies,  First Aid Supplies'}, 3), ({' Thermometer'}, 91), ({' Thermometer,  Thermometer,  Thermometer'}, 4), ({' Toothpaste,  Toothpaste,  Toothpaste'}, 2), ({' First Aid Supplies'}, 91), ({'Band-Aids'}, 96), ({' Band-Aids,  Toothpaste '}, 47), ({' Toothpaste '}, 4), ({' First Aid Supplies,  Insect Repellent'}, 6), ({'Eye Drops'}, 90), ({' Blood Pressure Monitor'}, 53), ({' Insect Repellent'}, 130), ({' Band-Aids'}, 65), ({'First Aid Supplies'}, 48), ({' Toothpaste'}, 64), ({' Thermometer,  Thermometer,  Cold and Flu Medicine '}, 2), ({' Blood Pressure Monitor,  Cold and Flu Medicine'}, 7), ({'Cold and Flu Medicine', ' Thermometer,  Thermometer'}, 41), ({'Cold and Flu Medicine', ' First Aid Supplies,  First Aid Supplies'}, 49), ({' Blood Pressure Monitor,  Cold and Flu Medicine ', 'Cold and Flu Medicine'}, 56), ({'Cold and Flu Medicine', ' Cold and Flu Medicine '}, 2), ({' First Aid Supplies,  First Aid Supplies,  First Aid Supplies', 'Cold and Flu Medicine'}, 3), ({' Blood Pressure Monitor', 'Cold and Flu Medicine'}, 4), ({' Insect Repellent', 'Cold and Flu Medicine'}, 63), ({'Cold and Flu Medicine', ' Thermometer,  Thermometer,  Cold and Flu Medicine '}, 2), ({'Cold and Flu Medicine', ' Blood Pressure Monitor,  Cold and Flu Medicine'}, 7), ({' Thermometer,  Blood Pressure Monitor ', 'Blood Pressure Monitor'}, 47), ({' First Aid Supplies,  Insect Repellent', ' Insect Repellent '}, 3), ({' Insect Repellent', ' Insect Repellent '}, 7), ({' Band-Aids', ' Insect Repellent '}, 3), ({' Insect Repellent ', ' Toothpaste'}, 3), ({' Eye Drops', ' Eye Drops '}, 10), ({' Eye Drops', ' Thermometer '}, 2), ({' Eye Drops', ' Thermometer'}, 5), ({' Eye Drops', 'Eye Drops'}, 8), ({' Eye Drops', ' Blood Pressure Monitor'}, 2), ({' Eye Drops ', ' Thermometer'}, 49), ({' Eye Drops ', 'Eye Drops'}, 89), ({' Blood Pressure Monitor', ' Eye Drops '}, 48), ({'Toothpaste', ' Band-Aids,  Toothpaste'}, 4), ({'Toothpaste', ' Band-Aids,  Toothpaste '}, 47), ({'Toothpaste', ' Toothpaste '}, 3), ({' Thermometer,  Insect Repellent ', 'Insect Repellent'}, 2), ({' Thermometer', 'Insect Repellent'}, 39), ({' First Aid Supplies', 'Insect Repellent'}, 43), ({' First Aid Supplies', ' First Aid Supplies '}, 46), ({'Band-Aids', ' First Aid Supplies '}, 46), ({' Cold and Flu Medicine', ' Band-Aids '}, 3), ({' Blood Pressure Monitor,  Band-Aids', ' Band-Aids '}, 3), ({'Band-Aids', ' Band-Aids '}, 3), ({' Thermometer ', ' Thermometer'}, 2), ({'First Aid Supplies', ' Thermometer,  Thermometer'}, 44), ({'Blood Pressure Monitor', ' Blood Pressure Monitor '}, 3), ({' Blood Pressure Monitor,  Band-Aids ', ' Cold and Flu Medicine'}, 47), ({' Blood Pressure Monitor,  Band-Aids ', 'Band-Aids'}, 47), ({' First Aid Supplies', ' Thermometer,  Insect Repellent '}, 2), ({' Blood Pressure Monitor,  Cold and Flu Medicine ', ' Insect Repellent'}, 56), ({' Blood Pressure Monitor,  Band-Aids', ' Cold and Flu Medicine'}, 3), ({' Cold and Flu Medicine', 'Band-Aids'}, 50), ({' Toothpaste ', ' Band-Aids,  Toothpaste'}, 3),  ...
# Association Rules: [({' First Aid Supplies,  First Aid Supplies'}, {'Cold and Flu Medicine'}, 1.0), ({' Blood Pressure Monitor,  Cold and Flu Medicine '}, {'Cold and Flu Medicine'}, 1.0), ({' Cold and Flu Medicine '}, {'Cold and Flu Medicine'}, 1.0), ({' First Aid Supplies,  First Aid Supplies,  First Aid Supplies'}, {'Cold and Flu Medicine'}, 1.0), ({' Thermometer,  Thermometer,  Cold and Flu Medicine '}, {'Cold and Flu Medicine'}, 1.0), ({' Blood Pressure Monitor,  Cold and Flu Medicine'}, {'Cold and Flu Medicine'}, 1.0), ({' Thermometer,  Blood Pressure Monitor '}, {'Blood Pressure Monitor'}, 1.0), ({'Blood Pressure Monitor'}, {' Thermometer,  Blood Pressure Monitor '}, 0.9215686274509803), ({' First Aid Supplies,  Insect Repellent'}, {' Insect Repellent '}, 0.5), ({' Eye Drops'}, {' Eye Drops '}, 0.7692307692307693), ({' Thermometer '}, {' Eye Drops'}, 1.0), ({' Eye Drops'}, {'Eye Drops'}, 0.6153846153846154), ({' Thermometer'}, {' Eye Drops '}, 0.5384615384615384), ({' Eye Drops '}, {'Eye Drops'}, 0.644927536231884), ({'Eye Drops'}, {' Eye Drops '}, 0.9888888888888889), ({' Blood Pressure Monitor'}, {' Eye Drops '}, 0.9056603773584906), ({' Band-Aids,  Toothpaste'}, {'Toothpaste'}, 1.0), ({'Toothpaste'}, {' Band-Aids,  Toothpaste '}, 0.9215686274509803), ({' Band-Aids,  Toothpaste '}, {'Toothpaste'}, 1.0), ({' Toothpaste '}, {'Toothpaste'}, 0.75), ({' Thermometer,  Insect Repellent '}, {'Insect Repellent'}, 1.0), ({'Insect Repellent'}, {' Thermometer'}, 0.9069767441860465), ({'Insect Repellent'}, {' First Aid Supplies'}, 1.0), ({' First Aid Supplies'}, {' First Aid Supplies '}, 0.5054945054945055), ({' First Aid Supplies '}, {' First Aid Supplies'}, 1.0), ({' First Aid Supplies '}, {'Band-Aids'}, 1.0), ({' Band-Aids '}, {' Cold and Flu Medicine'}, 1.0), ({' Blood Pressure Monitor,  Band-Aids'}, {' Band-Aids '}, 1.0), ({' Band-Aids '}, {' Blood Pressure Monitor,  Band-Aids'}, 1.0), ({' Band-Aids '}, {'Band-Aids'}, 1.0), ({' Thermometer '}, {' Thermometer'}, 1.0), ({'First Aid Supplies'}, {' Thermometer,  Thermometer'}, 0.9166666666666666), ({' Thermometer,  Thermometer'}, {'First Aid Supplies'}, 0.5116279069767442), ({' Blood Pressure Monitor '}, {'Blood Pressure Monitor'}, 0.75), ({' Blood Pressure Monitor,  Band-Aids '}, {' Cold and Flu Medicine'}, 1.0), ({' Cold and Flu Medicine'}, {' Blood Pressure Monitor,  Band-Aids '}, 0.94), ({' Blood Pressure Monitor,  Band-Aids '}, {'Band-Aids'}, 1.0), ({' Thermometer,  Insect Repellent '}, {' First Aid Supplies'}, 1.0), ({' Blood Pressure Monitor,  Cold and Flu Medicine '}, {' Insect Repellent'}, 1.0), ({' Blood Pressure Monitor,  Band-Aids'}, {' Cold and Flu Medicine'}, 1.0), ({' Cold and Flu Medicine'}, {'Band-Aids'}, 1.0), ({'Band-Aids'}, {' Cold and Flu Medicine'}, 0.5208333333333334), ({' Toothpaste '}, {' Band-Aids,  Toothpaste'}, 0.75), ({' Band-Aids,  Toothpaste'}, {' Toothpaste '}, 0.75), ({' Cold and Flu Medicine '}, {' Insect Repellent'}, 1.0), ({' Cold and Flu Medicine '}, {' Blood Pressure Monitor,  Cold and Flu Medicine'}, 1.0), ({' First Aid Supplies,  Insect Repellent '}, {' Insect Repellent'}, 1.0), ({' Band-Aids'}, {' First Aid Supplies,  Insect Repellent '}, 0.8923076923076924), ({' First Aid Supplies,  Insect Repellent '}, {' Band-Aids'}, 1.0), ({' First Aid Supplies,  Insect Repellent '}, {' Toothpaste'}, 1.0), ({' Toothpaste'}, {' First Aid Supplies,  Insect Repellent '}, 0.90625), ({' Blood Pressure Monitor,  Band-Aids'}, {'Band-Aids'}, 1.0), ({' Thermometer,  Thermometer,  Thermometer'}, {'First Aid Supplies'}, 0.75), ({' First Aid Supplies'}, {'Band-Aids'}, 0.5054945054945055), ({' First Aid Supplies,  Insect Repellent'}, {' Insect Repellent'}, 1.0), ({' First Aid Supplies,  Insect Repellent'}, {' Band-Aids'}, 1.0), ({' First Aid Supplies,  Insect Repellent'}, {' Toothpaste'}, 1.0), ({' Blood Pressure Monitor'}, {'Eye Drops'}, 0.9245283018867925), ({'Eye Drops'}, {' Blood Pressure Monitor'}, 0.5444444444444444), ({' Blood Pressure Monitor,  Cold and Flu  ...
#
#
# Results for C:\Users\Rushmitha K\Downloads\walmart_data.csv:
# Frequent Itemsets: [({' Trash Bags,  Toilet Paper '}, 46), ({' Trash Bags'}, 108), ({' Trash Bags,  Toilet Paper'}, 5), ({' Toilet Paper'}, 103), ({' Trash Bags,  Laundry Detergent '}, 45), ({' Lotion,  Trash Bags'}, 4), ({'Laundry Detergent'}, 98), ({' Lotion '}, 2), ({' Razors,  Razors'}, 50), ({' Paper Towels,  Paper Towels,  Paper Towels'}, 2), ({' Trash Bags,  Laundry Detergent'}, 3), ({' Dog Food,  Dog Food,  Dog Food'}, 7), ({' Lotion,  Lotion,  Lotion'}, 3), ({' Milk,  Lotion'}, 6), ({'Paper Towels,  Paper Towels,  Paper Towels'}, 2), ({' Paper Towels'}, 50), ({' Razors '}, 2), ({'Milk,  Milk,  Milk'}, 4), ({' Razors,  Milk'}, 4), ({' Milk '}, 2), ({'Paper Towels,  Paper Towels'}, 42), ({'Lotion'}, 47), ({' Toilet Paper,  Milk '}, 51), ({' Razors,  Milk '}, 95), ({' Paper Towels,  Paper Towels'}, 54), ({'Milk'}, 163), ({' Laundry Detergent '}, 51), ({' Milk'}, 53), ({' Milk,  Lotion '}, 41), ({'Razors,  Razors'}, 42), ({'Milk,  Milk'}, 47), ({' Lotion,  Lotion'}, 41), ({' Razors'}, 55), ({' Laundry Detergent'}, 150), ({' Trash Bags '}, 57), ({'Razors,  Razors,  Razors'}, 3), ({' Dog Food,  Laundry Detergent '}, 2), ({' Toilet Paper '}, 6), ({' Dog Food,  Razors '}, 50), ({' Toilet Paper,  Milk'}, 4), ({' Paper Towels,  Paper Towels,  Milk '}, 2), ({' Dog Food'}, 93), ({' Dog Food,  Dog Food'}, 51), ({' Dog Food,  Razors'}, 2), ({' Lotion,  Trash Bags '}, 47), ({'Dog Food'}, 106), ({' Trash Bags,  Toilet Paper ', ' Toilet Paper'}, 46), ({' Trash Bags', ' Lotion,  Trash Bags'}, 4), ({' Trash Bags', 'Laundry Detergent'}, 3), ({' Trash Bags', ' Trash Bags,  Laundry Detergent'}, 3), ({' Trash Bags', ' Laundry Detergent'}, 51), ({' Trash Bags', ' Trash Bags '}, 57), ({' Trash Bags', ' Dog Food'}, 51), ({' Trash Bags', ' Lotion,  Trash Bags '}, 47), ({' Trash Bags', 'Dog Food'}, 54), ({' Toilet Paper', ' Trash Bags,  Toilet Paper'}, 5), ({' Toilet Paper ', ' Trash Bags,  Toilet Paper'}, 5), ({' Paper Towels', ' Toilet Paper'}, 50), ({' Razors,  Milk', ' Toilet Paper'}, 2), ({' Toilet Paper', ' Razors,  Milk '}, 48), ({' Toilet Paper', 'Milk'}, 52), ({' Toilet Paper', ' Toilet Paper '}, 6), ({' Toilet Paper,  Milk', ' Toilet Paper'}, 2), ({'Laundry Detergent', ' Trash Bags,  Laundry Detergent '}, 45), ({' Lotion,  Trash Bags', ' Laundry Detergent'}, 4), ({' Trash Bags ', ' Lotion,  Trash Bags'}, 3), ({' Dog Food', ' Lotion,  Trash Bags'}, 4), ({'Laundry Detergent', ' Trash Bags,  Laundry Detergent'}, 3), ({'Laundry Detergent', ' Laundry Detergent '}, 50), ({'Laundry Detergent', ' Laundry Detergent'}, 3), ({' Lotion ', ' Milk,  Lotion'}, 2), ({' Lotion ', 'Lotion'}, 2), ({' Razors,  Razors', 'Dog Food'}, 50), ({' Paper Towels,  Paper Towels,  Paper Towels', 'Milk'}, 2), ({'Lotion', ' Milk,  Lotion'}, 6), ({' Milk', ' Milk,  Lotion'}, 4), ({' Paper Towels', ' Razors,  Milk'}, 2), ({' Paper Towels', ' Razors,  Milk '}, 48), ({' Paper Towels', 'Milk'}, 50), ({' Razors', ' Razors '}, 2), ({' Razors ', ' Dog Food,  Razors'}, 2), ({' Razors,  Milk', 'Milk'}, 2), ({' Milk', ' Razors,  Milk'}, 2), ({' Razors,  Milk', ' Razors'}, 3), ({' Razors,  Milk', ' Laundry Detergent'}, 2), ({'Milk', ' Milk '}, 2), ({' Toilet Paper,  Milk', ' Milk '}, 2), ({' Milk', 'Lotion'}, 4), ({' Milk,  Lotion ', 'Lotion'}, 41), ({'Milk', ' Toilet Paper,  Milk '}, 51), ({' Razors,  Milk ', 'Milk'}, 48), ({' Milk', ' Razors,  Milk '}, 47), ({' Razors,  Milk ', ' Laundry Detergent'}, 47), ({' Paper Towels,  Paper Towels', 'Milk'}, 54), ({' Toilet Paper,  Milk', 'Milk'}, 4), ({' Paper Towels,  Paper Towels,  Milk ', 'Milk'}, 2), ({' Laundry Detergent', ' Laundry Detergent '}, 4), ({' Milk', ' Razors'}, 2), ({' Milk', ' Laundry Detergent'}, 49), ({' Razors', ' Laundry Detergent'}, 2), ({' Razors', ' Dog Food,  Razors '}, 50), ({' Razors', ' Dog Food,  Razors'}, 2), ({' Trash Bags ', ' Laundry Detergent'}, 3), ({' Dog Food,  Laundry Detergent ', ' Laundry Detergent'}, 2), ({' Dog Food', ' Laundry Detergent'}, 93), ({' Dog Food,  Dog Food', ' Laundry Detergent'}, 3 ...
# Association Rules: [({' Trash Bags,  Toilet Paper '}, {' Toilet Paper'}, 1.0), ({' Lotion,  Trash Bags'}, {' Trash Bags'}, 1.0), ({' Trash Bags,  Laundry Detergent'}, {' Trash Bags'}, 1.0), ({' Trash Bags'}, {' Trash Bags '}, 0.5277777777777778), ({' Trash Bags '}, {' Trash Bags'}, 1.0), ({' Dog Food'}, {' Trash Bags'}, 0.5483870967741935), ({' Lotion,  Trash Bags '}, {' Trash Bags'}, 1.0), ({' Trash Bags'}, {'Dog Food'}, 0.5), ({'Dog Food'}, {' Trash Bags'}, 0.5094339622641509), ({' Trash Bags,  Toilet Paper'}, {' Toilet Paper'}, 1.0), ({' Toilet Paper '}, {' Trash Bags,  Toilet Paper'}, 0.8333333333333334), ({' Trash Bags,  Toilet Paper'}, {' Toilet Paper '}, 1.0), ({' Paper Towels'}, {' Toilet Paper'}, 1.0), ({' Razors,  Milk'}, {' Toilet Paper'}, 0.5), ({' Razors,  Milk '}, {' Toilet Paper'}, 0.5052631578947369), ({' Toilet Paper'}, {'Milk'}, 0.5048543689320388), ({' Toilet Paper '}, {' Toilet Paper'}, 1.0), ({' Toilet Paper,  Milk'}, {' Toilet Paper'}, 0.5), ({' Trash Bags,  Laundry Detergent '}, {'Laundry Detergent'}, 1.0), ({' Lotion,  Trash Bags'}, {' Laundry Detergent'}, 1.0), ({' Lotion,  Trash Bags'}, {' Trash Bags '}, 0.75), ({' Lotion,  Trash Bags'}, {' Dog Food'}, 1.0), ({' Trash Bags,  Laundry Detergent'}, {'Laundry Detergent'}, 1.0), ({'Laundry Detergent'}, {' Laundry Detergent '}, 0.5102040816326531), ({' Laundry Detergent '}, {'Laundry Detergent'}, 0.9803921568627451), ({' Lotion '}, {' Milk,  Lotion'}, 1.0), ({' Lotion '}, {'Lotion'}, 1.0), ({' Razors,  Razors'}, {'Dog Food'}, 1.0), ({' Paper Towels,  Paper Towels,  Paper Towels'}, {'Milk'}, 1.0), ({' Milk,  Lotion'}, {'Lotion'}, 1.0), ({' Milk,  Lotion'}, {' Milk'}, 0.6666666666666666), ({' Razors,  Milk'}, {' Paper Towels'}, 0.5), ({' Paper Towels'}, {' Razors,  Milk '}, 0.96), ({' Razors,  Milk '}, {' Paper Towels'}, 0.5052631578947369), ({' Paper Towels'}, {'Milk'}, 1.0), ({' Razors '}, {' Razors'}, 1.0), ({' Razors '}, {' Dog Food,  Razors'}, 1.0), ({' Dog Food,  Razors'}, {' Razors '}, 1.0), ({' Razors,  Milk'}, {'Milk'}, 0.5), ({' Razors,  Milk'}, {' Milk'}, 0.5), ({' Razors,  Milk'}, {' Razors'}, 0.75), ({' Razors,  Milk'}, {' Laundry Detergent'}, 0.5), ({' Milk '}, {'Milk'}, 1.0), ({' Toilet Paper,  Milk'}, {' Milk '}, 0.5), ({' Milk '}, {' Toilet Paper,  Milk'}, 1.0), ({' Milk,  Lotion '}, {'Lotion'}, 1.0), ({'Lotion'}, {' Milk,  Lotion '}, 0.8723404255319149), ({' Toilet Paper,  Milk '}, {'Milk'}, 1.0), ({' Razors,  Milk '}, {'Milk'}, 0.5052631578947369), ({' Milk'}, {' Razors,  Milk '}, 0.8867924528301887), ({' Paper Towels,  Paper Towels'}, {'Milk'}, 1.0), ({' Toilet Paper,  Milk'}, {'Milk'}, 1.0), ({' Paper Towels,  Paper Towels,  Milk '}, {'Milk'}, 1.0), ({' Milk'}, {' Laundry Detergent'}, 0.9245283018867925), ({' Razors'}, {' Dog Food,  Razors '}, 0.9090909090909091), ({' Dog Food,  Razors '}, {' Razors'}, 1.0), ({' Dog Food,  Razors'}, {' Razors'}, 1.0), ({' Dog Food,  Laundry Detergent '}, {' Laundry Detergent'}, 1.0), ({' Dog Food'}, {' Laundry Detergent'}, 1.0), ({' Laundry Detergent'}, {' Dog Food'}, 0.62), ({' Lotion,  Trash Bags '}, {' Laundry Detergent'}, 1.0), ({' Trash Bags '}, {'Dog Food'}, 0.9473684210526315), ({'Dog Food'}, {' Trash Bags '}, 0.5094339622641509), ({' Dog Food'}, {' Lotion,  Trash Bags '}, 0.5053763440860215), ({' Lotion,  Trash Bags '}, {' Dog Food'}, 1.0), ({' Lotion,  Trash Bags'}, {' Trash Bags', ' Laundry Detergent'}, 1.0), ({' Trash Bags', ' Lotion,  Trash Bags'}, {' Laundry Detergent'}, 1.0), ({' Lotion,  Trash Bags', ' Laundry Detergent'}, {' Trash Bags'}, 1.0), ({' Lotion,  Trash Bags'}, {' Trash Bags', ' Trash Bags '}, 0.75), ({' Trash Bags', ' Lotion,  Trash Bags'}, {' Trash Bags '}, 0.75), ({' Trash Bags ', ' Lotion,  Trash Bags'}, {' Trash Bags'}, 1.0), ({' Lotion,  Trash Bags'}, {' Trash Bags', ' Dog Food'}, 1.0), ({' Trash Bags', ' Lotion,  Trash Bags'}, {' Dog Food'}, 1.0), ({' Dog Food', ' Lotion,  Trash Bags'}, {' Trash Bags'}, 1.0), ({' Trash Bags,  Laundry Detergent'}, {' Trash Bags', 'Laundry D ...
#
#
# Time taken:
# 19.52736234664917

# %%
import pandas as pd
from time import time
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules


def load_transactions(file_path):
    df = pd.read_csv(file_path)
    transactions = df['Filtered Transaction'].apply(lambda x: x.split(', ')).tolist()
    return transactions


def analyze_dataset(file_path, min_support, min_confidence):
    start_time = time() 

    transactions = load_transactions(file_path)
    
    
    te = TransactionEncoder()
    te_ary = te.fit(transactions).transform(transactions)
    df = pd.DataFrame(te_ary, columns=te.columns_)
    
    
    frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)
    
    
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)
    
    print(f"Input Transactions for {file_path.split('/')[-1]}:")  
    for t in transactions:
        print(t)
        
    print("\nGenerated Association Rules:")
    print(rules[['antecedents', 'consequents', 'support', 'confidence']])
    

    elapsed_time = time() - start_time
    print(f"\n\nTime taken for {file_path.split('/')[-1]}: {elapsed_time:.2f} seconds\n")


def main():
    
    file_paths = [
    'C:\Users\Rushmitha K\Downloads\amazon_data.csv',
    'C:\Users\Rushmitha K\Downloads\costco_data.csv',
    'C:\Users\Rushmitha K\Downloads\best_buy_data.csv',
    'C:\Users\Rushmitha K\Downloads\walgreens_data.csv',
    'C:\Users\Rushmitha K\Downloads\walmart_data.csv'
    ]
    

    
    min_support = float(input("Enter minimum support value (e.g., 0.05 for 5%): "))
    min_confidence = float(input("Enter minimum confidence value (e.g., 0.5 for 50%): "))

    for file_path in file_paths:
        analyze_dataset(file_path, min_support, min_confidence)

if __name__ == "__main__":
    main()
# Out:
# Enter minimum support value (e.g., 0.05 for 5%):  0.1
# Enter minimum confidence value (e.g., 0.5 for 50%):  1
# Input Transactions for amazon_data.csv:
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Tea']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Diapers']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Diapers']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Tea', 'Tea']
# ['Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Cheese', 'Flour']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Diapers']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Tea']
# ['Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Detergent', 'Tea']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Juice', 'Tea', 'Juice']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Tea']
# ['Cheese', 'Cheese', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Flour', 'Cheese', 'Flour', 'Cheese']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Flour', 'Cheese', 'Flour']
# ['Flour', 'Cheese', 'Flour']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Flour', 'Juice', 'Juice']
# ['Cheese']
# ['Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar']
# ['Juice', 'Tea', 'Juice']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Juice', 'Tea', 'Juice']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese', 'Cheese']
# ['Juice', 'Tea', 'Juice', 'Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Tea']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Cheese']
# ['Tea']
# ['Diapers', 'Diapers']
# ['Cheese']
# ['Cheese', 'Cheese']
# ['Diapers', 'Diapers']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Sugar']
# ['Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Detergent', 'Tea']
# ['Tea']
# ['Cheese']
# ['Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Juice', 'Tea', 'Juice', 'Juice']
# ['Detergent', 'Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Tea']
# ['Juice', 'Tea', 'Juice']
# ['Tea']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo', 'Cheese']
# ['Detergent', 'Tea']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Diapers', 'Diapers']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Tea']
# ['Diapers', 'Diapers']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Tea']
# ['Diapers', 'Diapers']
# ['Sugar', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Diapers']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Tea', 'Tea']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Diapers']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Cheese', 'Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Diapers']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Detergent', 'Tea']
# ['Diapers', 'Diapers']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Tea', 'Tea']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Tea']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Cheese', 'Flour']
# ['Diapers', 'Diapers']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Cheese', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Tea']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Tea']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Diapers', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Tea']
# ['Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar', 'Sugar']
# ['Detergent', 'Tea']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Detergent', 'Tea']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar', 'Diapers']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Shampoo', 'Shampoo', 'Shampoo']
# ['Tea']
# ['Cheese']
# ['Diapers', 'Diapers']
# ['Sugar', 'Sugar']
# ['Diapers', 'Diapers']
# ['Diapers', 'Diapers']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Sugar', 'Sugar']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Cheese']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Diapers', 'Diapers']
# ['Cheese']
# ['Sugar', 'Sugar']
# ['Juice', 'Tea', 'Juice']
# ['Tea']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Tea']
# ['Detergent', 'Tea']
# ['Sugar', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Sugar', 'Sugar']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo', 'Detergent']
# ['Cheese', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Juice', 'Tea', 'Juice', 'Juice']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers', 'Diapers']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Tea']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Juice', 'Tea', 'Juice']
# ['Flour', 'Cheese', 'Flour']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Cheese', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Sugar', 'Sugar']
# ['Juice', 'Tea', 'Juice', 'Juice']
# ['Diapers', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Detergent', 'Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Tea']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Cheese', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Juice', 'Juice']
# ['Tea']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Detergent', 'Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Diapers', 'Diapers']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar', 'Sugar']
# ['Sugar', 'Sugar']
# ['Juice', 'Tea', 'Juice']
# ['Flour', 'Juice', 'Juice']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Detergent', 'Shampoo', 'Shampoo', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Flour', 'Cheese', 'Flour', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Diapers', 'Diapers']
# ['Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Diapers']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Juice', 'Tea', 'Juice']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Cheese', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Diapers', 'Diapers']
# ['Detergent', 'Tea']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Sugar']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Detergent', 'Tea']
# ['Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Sugar', 'Sugar']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Tea']
# ['Diapers', 'Diapers']
# ['Detergent', 'Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Diapers', 'Diapers']
# ['Tea', 'Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Flour', 'Juice', 'Juice']
# ['Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Diapers', 'Diapers']
# ['Juice', 'Tea', 'Juice']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Sugar']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Cheese', 'Flour']
# ['Diapers', 'Diapers']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Diapers', 'Diapers']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Juice', 'Tea', 'Juice']
# ['Cheese', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Diapers', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo', 'Shampoo']
# ['Cheese']
# ['Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Cheese', 'Flour']
# ['Diapers', 'Diapers']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese', 'Detergent']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Tea']
# ['Diapers', 'Diapers']
# ['Juice', 'Tea', 'Juice']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese', 'Detergent']
# ['Tea']
# ['Diapers', 'Diapers', 'Diapers']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Cheese', 'Cheese']
# ['Detergent', 'Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Tea', 'Detergent']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Cheese', 'Cheese']
# ['Diapers', 'Diapers']
# ['Tea']
# ['Juice', 'Tea', 'Juice']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Diapers']
# ['Sugar', 'Sugar']
# ['Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo', 'Shampoo']
# ['Flour', 'Cheese', 'Flour']
# ['Diapers', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers', 'Diapers']
# ['Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo', 'Detergent']
# ['Cheese', 'Cheese']
# ['Detergent', 'Tea']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Cheese']
# ['Cheese']
# ['Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Sugar', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar', 'Sugar']
# ['Diapers', 'Flour', 'Cheese', 'Diapers', 'Flour']
# ['Sugar', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Cheese']
# ['Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Sugar', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Tea']
# ['Juice', 'Tea', 'Juice']
# ['Diapers', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Diapers', 'Diapers']
# ['Juice', 'Tea', 'Juice']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Diapers', 'Diapers']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Tea']
# ['Juice', 'Tea', 'Juice']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Cheese', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Juice', 'Tea', 'Juice']
# ['Flour', 'Juice', 'Juice']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Tea']
# ['Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Diapers', 'Diapers']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Cheese']
# ['Cheese', 'Cheese']
# ['Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Tea']
# ['Diapers', 'Diapers', 'Diapers']
# ['Detergent', 'Tea']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Detergent', 'Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar', 'Sugar']
# ['Detergent', 'Tea', 'Detergent']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Tea']
# ['Detergent', 'Tea']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Diapers']
# ['Diapers', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Shampoo', 'Detergent', 'Detergent', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Tea']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Tea']
# ['Tea']
# ['Detergent', 'Shampoo', 'Shampoo', 'Detergent']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Tea']
# ['Tea']
# ['Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Flour', 'Cheese', 'Flour']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar', 'Sugar']
# ['Juice', 'Tea', 'Juice']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Cheese']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Cheese']
# ['Detergent', 'Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Flour', 'Juice', 'Juice']
# ['Diapers', 'Diapers']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Diapers', 'Diapers']
# ['Tea']
# ['Cheese']
# ['Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Sugar']
# ['Cheese']
# ['Tea']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Sugar', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Diapers', 'Diapers']
# ['Cheese', 'Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Diapers']
# ['Tea']
# ['Detergent', 'Tea', 'Detergent']
# ['Flour', 'Cheese', 'Flour']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Tea']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Diapers']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Sugar', 'Sugar']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese', 'Detergent']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Tea']
# ['Detergent', 'Tea']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Diapers']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar', 'Diapers']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Tea']
# ['Cheese', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Juice', 'Tea', 'Juice']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Flour', 'Cheese', 'Flour']
# ['Diapers', 'Diapers']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Flour', 'Juice', 'Juice', 'Flour']
# ['Flour', 'Cheese', 'Flour']
# ['Flour', 'Cheese', 'Flour']
# ['Tea']
# ['Cheese']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Detergent', 'Tea']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Flour', 'Juice', 'Juice']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Sugar', 'Sugar']
# ['Diapers', 'Diapers']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Flour', 'Juice', 'Juice']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Cheese', 'Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Diapers', 'Diapers']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Cheese', 'Cheese', 'Cheese']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Juice', 'Tea', 'Juice', 'Tea']
# ['Detergent', 'Tea']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Cheese', 'Flour']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Diapers']
# ['Flour', 'Cheese', 'Flour']
# ['Tea']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Cheese']
# ['Sugar', 'Sugar']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Cheese', 'Cheese']
# ['Detergent', 'Tea']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent', 'Detergent']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Cheese']
# ['Detergent', 'Tea']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Flour', 'Cheese', 'Flour']
# ['Cheese']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Cheese']
# ['Shampoo', 'Detergent', 'Detergent', 'Shampoo']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Detergent', 'Tea']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Tea']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Juice', 'Tea', 'Juice']
# ['Flour', 'Cheese', 'Flour', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Tea']
# ['Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Juice', 'Tea', 'Juice']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Cheese', 'Cheese', 'Cheese']
# ['Tea']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Tea']
# ['Cheese']
# ['Cheese']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Diapers']
# ['Sugar', 'Sugar']
# ['Flour', 'Juice', 'Juice']
# ['Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Tea']
# ['Diapers', 'Diapers']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo', 'Shampoo']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Tea']
# ['Cheese', 'Cheese']
# ['Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Flour', 'Cheese', 'Flour', 'Flour']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Tea']
# ['Tea']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Tea']
# ['Cheese', 'Cheese', 'Cheese']
# ['Detergent', 'Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Cheese', 'Cheese']
# ['Detergent', 'Tea']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Sugar', 'Sugar']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Detergent', 'Tea']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Tea']
# ['Diapers', 'Flour', 'Cheese', 'Diapers', 'Cheese']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Tea']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Diapers', 'Diapers']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Tea']
# ['Tea']
# ['Juice', 'Tea', 'Juice']
# ['Diapers', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Cheese']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Diapers', 'Diapers']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Detergent', 'Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Diapers', 'Diapers']
# ['Flour', 'Cheese', 'Flour']
# ['Cheese', 'Cheese']
# ['Diapers', 'Diapers']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Flour', 'Juice', 'Juice']
#
# Generated Association Rules:
#   antecedents  consequents   support  confidence
# 0   (Shampoo)  (Detergent)  0.149891         1.0
#
#
# Time taken for amazon_data.csv: 0.06 seconds
#
# Input Transactions for costco_data.csv:
# ['Bulk Fruits ', ' Bulk Fruits ']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# [' Bakery Items ', ' Optical Items', ' Optical Items', ' Optical Items']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# ['Jewelry ', ' Bulk Vegetables']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# [' Cleaning Supplies', ' Cleaning Supplies']
# [' Tires', ' Tires']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# ['Bakery Items ', ' Garden Supplies']
# ['Bulk Fruits ', ' Tires ', ' Jewelry', ' Tires ']
# ['Bakery Items ', ' Bulk Fruits ']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# ['Bulk Fruits ', ' Bulk Fruits ']
# ['Bakery Items ', ' Garden Supplies']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Optical Items', ' Optical Items']
# ['Optical Items', ' Optical Items']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# ['Bakery Items ', ' Bulk Fruits ']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# ['Bakery Items ', ' Bulk Fruits ']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# ['Bulk Fruits ', ' Bulk Fruits ']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# [' Cleaning Supplies', ' Cleaning Supplies']
# [' Cleaning Supplies', ' Cleaning Supplies']
# ['Bakery Items ', ' Bulk Fruits ']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# ['Jewelry ', ' Bulk Vegetables']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# ['Optical Items', ' Optical Items']
# ['Bakery Items ', ' Garden Supplies']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# ['Bulk Fruits ', ' Tires ', ' Jewelry', ' Tires ']
# ['Bakery Items ', ' Garden Supplies']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Jewelry ', ' Bulk Vegetables']
# ['Bulk Fruits ', ' Tires ', ' Jewelry', ' Tires ']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# ['Optical Items', ' Optical Items']
# ['Bulk Fruits ', ' Bulk Fruits ']
# ['Optical Items', ' Optical Items']
# ['Bulk Fruits ', ' Bulk Fruits ']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# ['Bulk Fruits ', ' Bulk Fruits ']
# ['Bulk Fruits ', ' Bulk Fruits ']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ', ' Garden Supplies ']
# ['Optical Items', ' Optical Items']
# ['Bakery Items ', ' Bulk Fruits ']
# ['Jewelry', ' Jewelry']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# ['Jewelry ', ' Bulk Vegetables']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Jewelry ', ' Bulk Vegetables']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# ['Bulk Fruits ', ' Tires ', ' Jewelry', ' Tires ']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# [' Garden Supplies']
# ['Bulk Fruits ', ' Bulk Fruits ']
# ['Jewelry ', ' Bulk Vegetables']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# ['Bulk Fruits ', ' Tires ', ' Jewelry', ' Tires ']
# ['Bakery Items ', ' Bulk Fruits ']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Jewelry ', ' Bulk Vegetables']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# ['Jewelry', ' Jewelry']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Bulk Fruits ', ' Bulk Fruits ']
# ['Jewelry ', ' Bulk Vegetables']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# ['Bulk Fruits ', ' Bulk Fruits ']
# ['Optical Items', ' Optical Items']
# [' Garden Supplies']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# ['Jewelry ', ' Bulk Vegetables']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# ['Bakery Items ', ' Bulk Fruits ']
# ['Jewelry', ' Jewelry']
# [' Garden Supplies']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# ['Bulk Fruits ', ' Bulk Fruits ']
# [' Cleaning Supplies', ' Cleaning Supplies']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# ['Bulk Fruits ', ' Bulk Fruits ']
# ['Jewelry', ' Jewelry']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# ['Bakery Items ', ' Garden Supplies']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# [' Cleaning Supplies', ' Cleaning Supplies']
# [' Tires', ' Tires']
# ['Bulk Fruits ', ' Bulk Fruits ']
# ['Jewelry', ' Jewelry']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# [' Garden Supplies']
# [' Garden Supplies']
# [' Cleaning Supplies', ' Cleaning Supplies']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# ['Jewelry ', ' Bulk Vegetables']
# [' Garden Supplies']
# ['Bakery Items ', ' Garden Supplies']
# ['Bakery Items ', ' Garden Supplies']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# ['Jewelry', ' Jewelry']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# [' Cleaning Supplies', ' Cleaning Supplies', ' Cleaning Supplies']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# ['Bakery Items ', ' Bulk Fruits ']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# [' Cleaning Supplies', ' Cleaning Supplies']
# ['Jewelry', ' Jewelry']
# ['Jewelry ', ' Bulk Vegetables']
# [' Garden Supplies']
# ['Optical Items', ' Optical Items']
# ['Bulk Fruits ', ' Tires ', ' Jewelry', ' Tires ']
# ['Bakery Items ', ' Garden Supplies']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# ['Bulk Fruits ', ' Bulk Fruits ']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# [' Cleaning Supplies', ' Cleaning Supplies']
# [' Cleaning Supplies', ' Cleaning Supplies']
# ['Bakery Items ', ' Bulk Fruits ']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# ['Bulk Fruits ', ' Bulk Fruits ']
# ['Bulk Fruits ', ' Tires ', ' Jewelry', ' Tires ']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ', ' Tires ']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# ['Bakery Items ', ' Garden Supplies']
# ['Bakery Items ', ' Bulk Fruits ']
# ['Optical Items', ' Optical Items']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# ['Jewelry', ' Jewelry']
# ['Bakery Items ', ' Bulk Fruits ']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# [' Cleaning Supplies', ' Cleaning Supplies']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Jewelry ', ' Bulk Vegetables']
# ['Jewelry', ' Jewelry', ' Jewelry']
# [' Tires', ' Tires']
# [' Cleaning Supplies', ' Cleaning Supplies']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# ['Bakery Items ', ' Bulk Fruits ']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# ['Bulk Fruits ', ' Bulk Fruits ']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# [' Cleaning Supplies', ' Cleaning Supplies', ' Cleaning Supplies']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# ['Jewelry', ' Jewelry']
# ['Bakery Items ', ' Garden Supplies']
# ['Bulk Fruits ', ' Tires ', ' Jewelry', ' Tires ']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# ['Bakery Items ', ' Garden Supplies']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# [' Garden Supplies']
# ['Bulk Fruits ', ' Tires ', ' Jewelry', ' Tires ']
# ['Jewelry ', ' Bulk Vegetables']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# [' Bakery Items ', ' Optical Items', ' Optical Items', ' Optical Items']
# ['Jewelry ', ' Bulk Vegetables']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# [' Tires', ' Tires']
# ['Jewelry ', ' Bulk Vegetables']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# ['Bakery Items ', ' Garden Supplies']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# ['Jewelry ', ' Bulk Vegetables']
# ['Bakery Items ', ' Bulk Fruits ']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# ['Bulk Fruits ', ' Bulk Fruits ']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# ['Bakery Items ', ' Garden Supplies']
# [' Tires', ' Tires']
# [' Cleaning Supplies', ' Cleaning Supplies']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# ['Jewelry', ' Jewelry']
# [' Bakery Items ', ' Optical Items', ' Optical Items', ' Bakery Items ']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# [' Cleaning Supplies', ' Cleaning Supplies']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# ['Bakery Items ', ' Bulk Fruits ']
# ['Jewelry', ' Jewelry']
# ['Bakery Items ', ' Bulk Fruits ']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# ['Jewelry', ' Jewelry']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ', ' Bulk Fruits ']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# ['Jewelry ', ' Bulk Vegetables', ' Bulk Vegetables']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# ['Jewelry ', ' Bulk Vegetables']
# [' Cleaning Supplies', ' Cleaning Supplies']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# [' Tires', ' Tires']
# ['Bulk Fruits ', ' Tires ', ' Jewelry', ' Tires ']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# ['Bulk Fruits ', ' Tires ', ' Jewelry', ' Tires ']
# [' Cleaning Supplies', ' Cleaning Supplies']
# [' Garden Supplies']
# ['Jewelry ', ' Bulk Vegetables']
# ['Jewelry ', ' Bulk Vegetables']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# [' Garden Supplies', ' Garden Supplies']
# [' Cleaning Supplies', ' Cleaning Supplies']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# [' Bakery Items ', ' Optical Items', ' Optical Items', ' Optical Items']
# ['Bulk Fruits ', ' Bulk Fruits ', ' Bulk Fruits ']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# ['Bakery Items ', ' Garden Supplies']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# ['Bakery Items ', ' Bulk Fruits ']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# ['Optical Items', ' Optical Items']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# [' Tires', ' Tires']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# [' Garden Supplies']
# [' Garden Supplies']
# [' Garden Supplies']
# [' Cleaning Supplies', ' Cleaning Supplies']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Bulk Fruits ', ' Bulk Fruits ', ' Bulk Fruits ']
# ['Optical Items', ' Optical Items']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ', ' Bulk Vegetables ']
# ['Jewelry', ' Jewelry']
# ['Jewelry', ' Jewelry']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# ['Optical Items', ' Optical Items']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# ['Jewelry ', ' Bulk Vegetables']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# ['Bakery Items ', ' Bulk Fruits ']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# [' Cleaning Supplies', ' Cleaning Supplies']
# [' Bakery Items ', ' Optical Items', ' Optical Items', ' Optical Items']
# [' Tires', ' Tires']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# ['Bakery Items ', ' Garden Supplies', ' Bakery Items ']
# [' Cleaning Supplies', ' Cleaning Supplies']
# [' Cleaning Supplies', ' Cleaning Supplies']
# ['Bakery Items ', ' Garden Supplies']
# ['Bulk Fruits ', ' Bulk Fruits ']
# ['Jewelry ', ' Bulk Vegetables']
# ['Bulk Fruits ', ' Bulk Fruits ']
# [' Cleaning Supplies', ' Cleaning Supplies']
# ['Jewelry', ' Jewelry']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# [' Cleaning Supplies', ' Cleaning Supplies']
# ['Bakery Items ', ' Bulk Fruits ']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ', ' Tires ']
# [' Garden Supplies']
# ['Jewelry', ' Jewelry']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# ['Optical Items', ' Optical Items']
# ['Jewelry ', ' Bulk Vegetables']
# ['Jewelry ', ' Bulk Vegetables']
# [' Cleaning Supplies', ' Cleaning Supplies']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# [' Garden Supplies']
# [' Garden Supplies']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# [' Cleaning Supplies', ' Cleaning Supplies']
# ['Bulk Fruits ', ' Tires ', ' Jewelry', ' Tires ']
# ['Bakery Items ', ' Garden Supplies']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# ['Jewelry ', ' Bulk Vegetables']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# [' Tires', ' Tires']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# ['Jewelry ', ' Bulk Vegetables']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# ['Bakery Items ', ' Garden Supplies']
# ['Bakery Items ', ' Bulk Fruits ']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# [' Tires', ' Tires']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# ['Bakery Items ', ' Bulk Fruits ']
# ['Bakery Items ', ' Bulk Fruits ']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# [' Cleaning Supplies', ' Cleaning Supplies']
# ['Jewelry', ' Jewelry']
# ['Jewelry', ' Jewelry']
# ['Bakery Items ', ' Garden Supplies']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# ['Optical Items', ' Optical Items']
# ['Optical Items', ' Optical Items']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Jewelry', ' Jewelry']
# ['Optical Items', ' Optical Items']
# [' Garden Supplies']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# ['Jewelry ', ' Bulk Vegetables']
# [' Tires', ' Tires']
# ['Jewelry ', ' Bulk Vegetables']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# [' Tires', ' Tires']
# [' Cleaning Supplies', ' Cleaning Supplies']
# ['Jewelry ', ' Bulk Vegetables']
# [' Garden Supplies']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# ['Bulk Fruits ', ' Tires ', ' Jewelry', ' Tires ']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Bulk Fruits ', ' Tires ', ' Jewelry', ' Tires ']
# [' Tires', ' Tires']
# ['Optical Items', ' Optical Items', ' Optical Items']
# ['Bakery Items ', ' Bulk Fruits ']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ', ' Tires ']
# [' Cleaning Supplies', ' Cleaning Supplies']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# [' Garden Supplies']
# ['Bulk Fruits ', ' Tires ', ' Jewelry', ' Tires ']
# [' Garden Supplies']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# ['Bulk Fruits ', ' Bulk Fruits ']
# ['Bulk Fruits ', ' Tires ', ' Jewelry', ' Tires ']
# ['Jewelry', ' Jewelry']
# ['Bulk Fruits ', ' Bulk Fruits ']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# ['Bulk Fruits ', ' Tires ', ' Jewelry', ' Tires ']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# [' Tires', ' Tires']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Bakery Items ', ' Garden Supplies']
# ['Bakery Items ', ' Garden Supplies']
# ['Jewelry', ' Jewelry']
# ['Jewelry ', ' Bulk Vegetables']
# ['Jewelry', ' Jewelry']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# ['Bakery Items ', ' Bulk Fruits ']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# ['Bakery Items ', ' Bulk Fruits ']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# ['Bulk Fruits ', ' Bulk Fruits ']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# ['Bakery Items ', ' Garden Supplies']
# ['Bakery Items ', ' Bulk Fruits ']
# ['Bakery Items ', ' Optical Items ', ' Cleaning Supplies', ' Cleaning Supplies']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# ['Garden Supplies ', ' Tires ', ' Garden Supplies ']
# ['Jewelry ', ' Bulk Vegetables']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# ['Jewelry', ' Jewelry']
# ['Bakery Items ', ' Bulk Fruits', ' Bulk Fruits']
# ['Optical Items', ' Optical Items']
# [' Optical Items ', ' Bulk Fruits ', ' Bulk Fruits ']
# ['Jewelry', ' Jewelry']
# [' Bakery Items ', ' Optical Items', ' Optical Items']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# ['Jewelry ', ' Bulk Vegetables']
# ['Cleaning Supplies ', ' Garden Supplies ', ' Bulk Vegetables ', ' Garden Supplies ']
# [' Garden Supplies']
# ['Bulk Fruits ', ' Bulk Fruits ']
# [' Bulk Vegetables ', ' Tires ', ' Garden Supplies', ' Bulk Vegetables ']
# ['Bulk Fruits ', ' Bulk Fruits ']
# ['Optical Items', ' Optical Items']
# [' Jewelry ', ' Bulk Fruits ', ' Optical Items', ' Optical Items']
# [' Cleaning Supplies', ' Cleaning Supplies']
# ['Bakery Items ', ' Garden Supplies']
# ...
# [' Laundry Detergent ', ' Dog Food']
# ['Razors', ' Razors']
# [' Toilet Paper ', ' Trash Bags', ' Toilet Paper ']
# ['Lotion ', ' Milk', ' Lotion ']
# ['Milk ', ' Toilet Paper', ' Milk ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# ['Milk ', ' Toilet Paper', ' Milk ', ' Milk ']
# ['Laundry Detergent ', ' Laundry Detergent ']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# [' Laundry Detergent ', ' Dog Food']
# ['Lotion ', ' Milk', ' Lotion ']
# [' Lotion', ' Lotion']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# [' Toilet Paper ', ' Trash Bags', ' Toilet Paper ']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# ['Paper Towels', ' Paper Towels']
# ['Milk ', ' Paper Towels', ' Paper Towels', ' Milk ']
# ['Dog Food ', ' Razors', ' Razors']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# [' Dog Food', ' Dog Food']
# ['Laundry Detergent ', ' Trash Bags', ' Laundry Detergent ']
# ['Milk ', ' Toilet Paper', ' Milk ']
# ['Milk ', ' Toilet Paper', ' Milk ']
# ['Lotion ', ' Milk', ' Lotion ']
# ['Laundry Detergent ', ' Laundry Detergent ']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# [' Toilet Paper ', ' Trash Bags', ' Toilet Paper ']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# [' Dog Food', ' Dog Food']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# ['Laundry Detergent ', ' Trash Bags', ' Laundry Detergent ']
# ['Milk', ' Milk']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# ['Milk', ' Milk']
# [' Laundry Detergent ', ' Dog Food']
# [' Lotion', ' Lotion']
# ['Laundry Detergent ', ' Trash Bags', ' Laundry Detergent ']
# ['Dog Food ', ' Razors', ' Razors']
# [' Razors ', ' Dog Food', ' Razors ']
# ['Paper Towels', ' Paper Towels']
# [' Razors ', ' Dog Food', ' Razors ']
# [' Lotion', ' Lotion']
# ['Milk ', ' Toilet Paper', ' Milk ']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# ['Dog Food ', ' Razors', ' Razors']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# ['Razors', ' Razors']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# [' Toilet Paper ', ' Trash Bags', ' Toilet Paper ']
# [' Laundry Detergent ', ' Dog Food']
# ['Milk', ' Milk']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# ['Dog Food ', ' Razors', ' Razors']
# ['Milk ', ' Toilet Paper', ' Milk ']
# [' Toilet Paper ', ' Trash Bags', ' Toilet Paper ']
# ['Paper Towels', ' Paper Towels']
# ['Laundry Detergent ', ' Trash Bags', ' Laundry Detergent ']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# ['Laundry Detergent ', ' Trash Bags', ' Laundry Detergent ']
# ['Lotion ', ' Milk', ' Lotion ', ' Milk']
# ['Milk ', ' Toilet Paper', ' Milk ', ' Toilet Paper']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# [' Laundry Detergent ', ' Dog Food', ' Dog Food']
# ['Laundry Detergent ', ' Laundry Detergent ']
# ['Milk ', ' Toilet Paper', ' Milk ']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# ['Milk', ' Milk', ' Milk']
# ['Laundry Detergent ', ' Trash Bags', ' Laundry Detergent ']
# ['Dog Food ', ' Razors', ' Razors']
# ['Paper Towels', ' Paper Towels']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# ['Dog Food ', ' Razors', ' Razors']
# ['Razors', ' Razors']
# ['Laundry Detergent ', ' Laundry Detergent ']
# ['Dog Food ', ' Razors', ' Razors']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# [' Razors ', ' Dog Food', ' Razors ']
# ['Laundry Detergent ', ' Laundry Detergent ']
# [' Lotion', ' Lotion']
# ['Laundry Detergent ', ' Trash Bags', ' Laundry Detergent ']
# ['Milk ', ' Toilet Paper', ' Milk ']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# [' Toilet Paper ', ' Trash Bags', ' Toilet Paper ']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# ['Milk ', ' Toilet Paper', ' Milk ']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# ['Lotion ', ' Milk', ' Lotion ']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ', ' Trash Bags ']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# ['Milk ', ' Toilet Paper', ' Milk ']
# [' Laundry Detergent ', ' Dog Food']
# [' Toilet Paper ', ' Trash Bags', ' Toilet Paper ']
# [' Laundry Detergent ', ' Dog Food']
# ['Dog Food ', ' Razors', ' Razors']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# [' Lotion', ' Lotion']
# ['Milk ', ' Toilet Paper', ' Milk ']
# ['Laundry Detergent ', ' Laundry Detergent ', ' Laundry Detergent ']
# ['Paper Towels', ' Paper Towels']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# ['Milk ', ' Toilet Paper', ' Milk ']
# ['Laundry Detergent ', ' Laundry Detergent ']
# ['Lotion ', ' Milk', ' Lotion ']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# [' Toilet Paper ', ' Trash Bags', ' Toilet Paper ', ' Toilet Paper ']
# [' Toilet Paper ', ' Trash Bags', ' Toilet Paper ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# ['Laundry Detergent ', ' Trash Bags', ' Laundry Detergent ']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# [' Lotion', ' Lotion']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# ['Lotion ', ' Milk', ' Lotion ', ' Milk']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# [' Laundry Detergent ', ' Dog Food']
# ['Milk ', ' Toilet Paper', ' Milk ']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# [' Dog Food', ' Dog Food']
# ['Lotion ', ' Milk', ' Lotion ']
# ['Milk', ' Milk']
# [' Lotion', ' Lotion']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ', ' Trash Bags ']
# ['Laundry Detergent ', ' Trash Bags', ' Laundry Detergent ']
# ['Laundry Detergent ', ' Trash Bags', ' Laundry Detergent ', ' Trash Bags']
# ['Laundry Detergent ', ' Trash Bags', ' Laundry Detergent ']
# ['Milk ', ' Toilet Paper', ' Milk ']
# ['Milk', ' Milk']
# [' Lotion', ' Lotion']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# [' Toilet Paper ', ' Trash Bags', ' Toilet Paper ']
# [' Lotion', ' Lotion']
# [' Razors ', ' Dog Food', ' Razors ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# ['Dog Food ', ' Razors', ' Razors']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# ['Laundry Detergent ', ' Laundry Detergent ']
# ['Lotion ', ' Milk', ' Lotion ']
# ['Dog Food ', ' Razors', ' Razors']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# [' Laundry Detergent ', ' Dog Food', ' Laundry Detergent ']
# ['Dog Food ', ' Razors', ' Razors']
# [' Dog Food', ' Dog Food']
# ['Dog Food ', ' Razors', ' Razors']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# ['Lotion ', ' Milk', ' Lotion ']
# ['Laundry Detergent ', ' Laundry Detergent ']
# ['Milk ', ' Toilet Paper', ' Milk ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# [' Lotion', ' Lotion']
# ['Razors', ' Razors']
# ['Milk', ' Milk']
# ['Milk', ' Milk']
# [' Dog Food', ' Dog Food']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# [' Razors ', ' Dog Food', ' Razors ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# ['Lotion ', ' Milk', ' Lotion ']
# ['Razors', ' Razors']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# ['Laundry Detergent ', ' Laundry Detergent ']
# ['Milk ', ' Toilet Paper', ' Milk ']
# ['Laundry Detergent ', ' Laundry Detergent ', ' Laundry Detergent ']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# ['Milk', ' Milk']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# ['Laundry Detergent ', ' Trash Bags', ' Laundry Detergent ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# ['Milk', ' Milk']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# ['Razors', ' Razors']
# ['Laundry Detergent ', ' Laundry Detergent ']
# ['Dog Food ', ' Razors', ' Razors']
# ['Razors', ' Razors']
# ['Razors', ' Razors']
# [' Laundry Detergent ', ' Dog Food']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# ['Lotion ', ' Milk', ' Lotion ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# ['Milk ', ' Toilet Paper', ' Milk ']
# ['Laundry Detergent ', ' Laundry Detergent ']
# [' Toilet Paper ', ' Trash Bags', ' Toilet Paper ', ' Toilet Paper ']
# ['Lotion ', ' Milk', ' Lotion ']
# [' Dog Food', ' Dog Food']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# ['Laundry Detergent ', ' Trash Bags', ' Laundry Detergent ', ' Trash Bags']
# ['Dog Food ', ' Razors', ' Razors']
# ['Dog Food ', ' Razors', ' Razors']
# ['Milk ', ' Toilet Paper', ' Milk ', ' Toilet Paper']
# [' Toilet Paper ', ' Trash Bags', ' Toilet Paper ']
# ['Milk ', ' Toilet Paper', ' Milk ']
# [' Razors ', ' Dog Food', ' Razors ']
# ['Laundry Detergent ', ' Laundry Detergent ']
# ['Lotion ', ' Milk', ' Lotion ']
# [' Dog Food', ' Dog Food']
# ['Milk ', ' Toilet Paper', ' Milk ']
# ['Lotion ', ' Milk', ' Lotion ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# ['Milk', ' Milk']
# [' Razors ', ' Dog Food', ' Razors ']
# ['Dog Food ', ' Razors', ' Razors']
# ['Dog Food ', ' Razors', ' Razors']
# ['Laundry Detergent ', ' Laundry Detergent ']
# [' Dog Food', ' Dog Food']
# [' Lotion', ' Lotion']
# ['Paper Towels', ' Paper Towels']
# ['Paper Towels', ' Paper Towels']
# ['Paper Towels', ' Paper Towels']
# [' Laundry Detergent ', ' Dog Food']
# ['Lotion ', ' Milk', ' Lotion ']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# ['Laundry Detergent ', ' Laundry Detergent ']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ', ' Toilet Paper ']
# [' Laundry Detergent ', ' Dog Food']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# [' Laundry Detergent ', ' Dog Food']
# ['Milk', ' Milk']
# ['Lotion ', ' Milk', ' Lotion ']
# ['Milk ', ' Toilet Paper', ' Milk ']
# ['Dog Food ', ' Razors', ' Razors']
# ['Paper Towels', ' Paper Towels']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# [' Dog Food', ' Dog Food']
# [' Razors ', ' Dog Food', ' Razors ']
# [' Razors ', ' Dog Food', ' Razors ']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# [' Toilet Paper ', ' Trash Bags', ' Toilet Paper ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# [' Dog Food', ' Dog Food']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# ['Dog Food ', ' Razors', ' Razors']
# ['Laundry Detergent ', ' Laundry Detergent ']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# [' Razors ', ' Dog Food', ' Razors ']
# ['Lotion ', ' Milk', ' Lotion ']
# [' Dog Food', ' Dog Food']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# ['Milk ', ' Toilet Paper', ' Milk ']
# ['Paper Towels', ' Paper Towels']
# ['Milk ', ' Toilet Paper', ' Milk ']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ', ' Razors']
# ['Razors', ' Razors']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# ['Laundry Detergent ', ' Trash Bags', ' Laundry Detergent ']
# ['Milk', ' Milk']
# [' Razors ', ' Dog Food', ' Razors ']
# ['Razors', ' Razors', ' Razors']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# [' Razors ', ' Dog Food', ' Razors ']
# ['Paper Towels', ' Paper Towels']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# [' Razors ', ' Dog Food', ' Razors ']
# ['Milk', ' Milk']
# ['Lotion ', ' Milk', ' Lotion ']
# [' Toilet Paper ', ' Trash Bags', ' Toilet Paper ']
# ['Dog Food ', ' Razors', ' Razors']
# ['Milk', ' Milk']
# ['Milk', ' Milk', ' Milk']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# [' Razors ', ' Dog Food', ' Razors ']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# [' Lotion', ' Lotion']
# ['Razors', ' Razors']
# ['Paper Towels', ' Paper Towels']
# [' Lotion', ' Lotion']
# [' Dog Food', ' Dog Food']
# [' Dog Food', ' Dog Food']
# ['Milk ', ' Toilet Paper', ' Milk ']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# [' Razors ', ' Dog Food', ' Razors ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# ['Razors', ' Razors']
# ['Lotion ', ' Milk', ' Lotion ']
# ['Razors', ' Razors']
# ['Razors', ' Razors']
# [' Toilet Paper ', ' Trash Bags', ' Toilet Paper ']
# ['Paper Towels', ' Paper Towels']
# [' Laundry Detergent ', ' Dog Food']
# ['Paper Towels', ' Paper Towels']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# ['Milk', ' Milk']
# ['Paper Towels', ' Paper Towels']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# [' Razors ', ' Dog Food', ' Razors ']
# ['Milk ', ' Toilet Paper', ' Milk ']
# ['Dog Food ', ' Razors', ' Razors']
# ['Razors', ' Razors']
# ['Laundry Detergent ', ' Laundry Detergent ']
# [' Lotion', ' Lotion']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# [' Laundry Detergent ', ' Dog Food']
# ['Lotion ', ' Milk', ' Lotion ']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# [' Lotion', ' Lotion']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# ['Razors', ' Razors']
# ['Dog Food ', ' Razors', ' Razors']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# ['Laundry Detergent ', ' Trash Bags', ' Laundry Detergent ']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# [' Laundry Detergent ', ' Trash Bags ', ' Dog Food ', ' Lotion', ' Trash Bags ']
# [' Razors ', ' Dog Food', ' Razors ']
# ['Paper Towels', ' Paper Towels']
# ['Milk', ' Milk']
# ['Paper Towels', ' Paper Towels']
# [' Dog Food', ' Dog Food']
# ['Laundry Detergent ', ' Trash Bags', ' Laundry Detergent ']
# ['Lotion ', ' Milk', ' Lotion ']
# ['Milk ', ' Toilet Paper', ' Milk ']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# [' Razors ', ' Dog Food', ' Razors ']
# [' Lotion', ' Lotion']
# ['Lotion ', ' Milk', ' Lotion ']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# ['Paper Towels', ' Paper Towels']
# ['Milk', ' Milk']
# [' Lotion', ' Lotion']
# [' Milk ', ' Laundry Detergent ', ' Razors', ' Milk ']
# [' Lotion', ' Lotion']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# ['Razors', ' Razors']
# [' Laundry Detergent ', ' Dog Food']
# ['Dog Food ', ' Razors', ' Razors']
# ['Paper Towels', ' Paper Towels']
# [' Toilet Paper ', ' Trash Bags', ' Toilet Paper ']
# [' Lotion', ' Lotion']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# ['Lotion ', ' Milk', ' Lotion ', ' Lotion ']
# ['Milk ', ' Toilet Paper ', ' Paper Towels ', ' Razors', ' Milk ']
# [' Razors ', ' Dog Food', ' Razors ', ' Razors ']
# ['Laundry Detergent ', ' Trash Bags', ' Laundry Detergent ']
# ['Milk ', ' Paper Towels', ' Paper Towels']
# [' Razors ', ' Dog Food', ' Razors ']
# ['Dog Food ', ' Trash Bags ', ' Trash Bags ']
# [' Razors ', ' Dog Food', ' Razors ']
#
# Generated Association Rules:
#             antecedents            consequents   support  confidence
# 0  (Laundry Detergent )  ( Laundry Detergent )  0.108527         1.0
#
#
# Time taken for walmart_data.csv: 0.02 seconds

# %%
import pandas as pd
from time import time
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules


def load_transactions(file_path):
    df = pd.read_csv(file_path)
    transactions = df['Filtered Transaction'].apply(lambda x: x.split(', ')).tolist()
    return transactions


def analyze_dataset(file_path, min_support, min_confidence):
    start_time = time()  

    transactions = load_transactions(file_path)
    
    
    te = TransactionEncoder()
    te_ary = te.fit(transactions).transform(transactions)
    df = pd.DataFrame(te_ary, columns=te.columns_)
    
    
    frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)
    
    
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)
    
    print(f"Input Transactions for {file_path.split('/')[-1]}:")  
    for t in transactions:
        print(t)
        
    print("\nGenerated Association Rules:")
    print(rules[['antecedents', 'consequents', 'support', 'confidence']])
    
    
    elapsed_time = time() - start_time
    print(f"\n\nTime taken for {file_path.split('/')[-1]}: {elapsed_time:.2f} seconds\n")


def main():
    
    datasets = {
        1:'C:\Users\Rushmitha K\Downloads\amazon_data.csv',
        2:'C:\Users\Rushmitha K\Downloads\costco_data.csv',
        3:'C:\Users\Rushmitha K\Downloads\best_buy_data.csv',
        4:'C:\Users\Rushmitha K\Downloads\walgreens_data.csv',
        5:'C:\Users\Rushmitha K\Downloads\walmart_data.csv''
    }
    
    
    print("Select the dataset(s) to analyze:")
    for key, value in datasets.items():
        print(f"{key} - {value.split('/')[-1]}")
    
    
    selections = input("Enter your choice(s) separated by commas (e.g., 1,3,5): ")
    selected_datasets = selections.split(',')
    
    
    min_support = float(input("Enter minimum support value (e.g., 0.05 for 5%): "))
    min_confidence = float(input("Enter minimum confidence value (e.g., 0.5 for 50%): "))

    
    for selection in selected_datasets:
        selected_path = datasets[int(selection)]
        analyze_dataset(selected_path, min_support, min_confidence)

if __name__ == "__main__":
    main()
# Out:
# Select the dataset(s) to analyze:
# 1 - amazon_data.csv
# 2 - costco_data.csv
# 3 - best_buy_data.csv
# 4 - walgreens_data.csv
# 5 - walmart_data.csv
# Enter your choice(s) separated by commas (e.g., 1,3,5):  1
# Enter minimum support value (e.g., 0.05 for 5%):  0.3
# Enter minimum confidence value (e.g., 0.5 for 50%):  1.0
# Input Transactions for amazon_data.csv:
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Tea']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Diapers']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Diapers']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Tea', 'Tea']
# ['Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Cheese', 'Flour']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Diapers']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Tea']
# ['Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Detergent', 'Tea']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Juice', 'Tea', 'Juice']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Tea']
# ['Cheese', 'Cheese', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Flour', 'Cheese', 'Flour', 'Cheese']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Flour', 'Cheese', 'Flour']
# ['Flour', 'Cheese', 'Flour']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Flour', 'Juice', 'Juice']
# ['Cheese']
# ['Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar']
# ['Juice', 'Tea', 'Juice']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Juice', 'Tea', 'Juice']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese', 'Cheese']
# ['Juice', 'Tea', 'Juice', 'Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Tea']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Cheese']
# ['Tea']
# ['Diapers', 'Diapers']
# ['Cheese']
# ['Cheese', 'Cheese']
# ['Diapers', 'Diapers']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Sugar']
# ['Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Detergent', 'Tea']
# ['Tea']
# ['Cheese']
# ['Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Juice', 'Tea', 'Juice', 'Juice']
# ['Detergent', 'Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Tea']
# ['Juice', 'Tea', 'Juice']
# ['Tea']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo', 'Cheese']
# ['Detergent', 'Tea']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Diapers', 'Diapers']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Tea']
# ['Diapers', 'Diapers']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Tea']
# ['Diapers', 'Diapers']
# ['Sugar', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Diapers']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Tea', 'Tea']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Diapers']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Cheese', 'Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Diapers']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Detergent', 'Tea']
# ['Diapers', 'Diapers']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Tea', 'Tea']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Tea']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Cheese', 'Flour']
# ['Diapers', 'Diapers']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Cheese', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Tea']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Tea']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Diapers', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Tea']
# ['Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar', 'Sugar']
# ['Detergent', 'Tea']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Detergent', 'Tea']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar', 'Diapers']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Shampoo', 'Shampoo', 'Shampoo']
# ['Tea']
# ['Cheese']
# ['Diapers', 'Diapers']
# ['Sugar', 'Sugar']
# ['Diapers', 'Diapers']
# ['Diapers', 'Diapers']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Sugar', 'Sugar']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Cheese']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Diapers', 'Diapers']
# ['Cheese']
# ['Sugar', 'Sugar']
# ['Juice', 'Tea', 'Juice']
# ['Tea']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Tea']
# ['Detergent', 'Tea']
# ['Sugar', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Sugar', 'Sugar']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo', 'Detergent']
# ['Cheese', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Juice', 'Tea', 'Juice', 'Juice']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers', 'Diapers']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Tea']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Juice', 'Tea', 'Juice']
# ['Flour', 'Cheese', 'Flour']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Cheese', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Sugar', 'Sugar']
# ['Juice', 'Tea', 'Juice', 'Juice']
# ['Diapers', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Detergent', 'Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Tea']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Cheese', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Juice', 'Juice']
# ['Tea']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Detergent', 'Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Diapers', 'Diapers']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar', 'Sugar']
# ['Sugar', 'Sugar']
# ['Juice', 'Tea', 'Juice']
# ['Flour', 'Juice', 'Juice']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Detergent', 'Shampoo', 'Shampoo', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Flour', 'Cheese', 'Flour', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Diapers', 'Diapers']
# ['Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Diapers']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Juice', 'Tea', 'Juice']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Cheese', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Diapers', 'Diapers']
# ['Detergent', 'Tea']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Sugar']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Detergent', 'Tea']
# ['Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Sugar', 'Sugar']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Tea']
# ['Diapers', 'Diapers']
# ['Detergent', 'Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Diapers', 'Diapers']
# ['Tea', 'Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Flour', 'Juice', 'Juice']
# ['Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Diapers', 'Diapers']
# ['Juice', 'Tea', 'Juice']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Sugar']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Cheese', 'Flour']
# ['Diapers', 'Diapers']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Diapers', 'Diapers']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Juice', 'Tea', 'Juice']
# ['Cheese', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Diapers', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo', 'Shampoo']
# ['Cheese']
# ['Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Cheese', 'Flour']
# ['Diapers', 'Diapers']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese', 'Detergent']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Tea']
# ['Diapers', 'Diapers']
# ['Juice', 'Tea', 'Juice']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese', 'Detergent']
# ['Tea']
# ['Diapers', 'Diapers', 'Diapers']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Cheese', 'Cheese']
# ['Detergent', 'Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Tea', 'Detergent']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Cheese', 'Cheese']
# ['Diapers', 'Diapers']
# ['Tea']
# ['Juice', 'Tea', 'Juice']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Diapers']
# ['Sugar', 'Sugar']
# ['Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo', 'Shampoo']
# ['Flour', 'Cheese', 'Flour']
# ['Diapers', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers', 'Diapers']
# ['Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo', 'Detergent']
# ['Cheese', 'Cheese']
# ['Detergent', 'Tea']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Cheese']
# ['Cheese']
# ['Sugar', 'Sugar']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Sugar', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar', 'Sugar']
# ['Diapers', 'Flour', 'Cheese', 'Diapers', 'Flour']
# ['Sugar', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Cheese']
# ['Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Sugar', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Tea']
# ['Juice', 'Tea', 'Juice']
# ['Diapers', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Diapers', 'Diapers']
# ['Juice', 'Tea', 'Juice']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Diapers', 'Diapers']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Tea']
# ['Juice', 'Tea', 'Juice']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Cheese', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Juice', 'Tea', 'Juice']
# ['Flour', 'Juice', 'Juice']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Tea']
# ['Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Diapers', 'Diapers']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Cheese']
# ['Cheese', 'Cheese']
# ['Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Tea']
# ['Diapers', 'Diapers', 'Diapers']
# ['Detergent', 'Tea']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Detergent', 'Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar', 'Sugar']
# ['Detergent', 'Tea', 'Detergent']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Tea']
# ['Detergent', 'Tea']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Diapers']
# ['Diapers', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Shampoo', 'Detergent', 'Detergent', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Tea']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Tea']
# ['Tea']
# ['Detergent', 'Shampoo', 'Shampoo', 'Detergent']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Tea']
# ['Tea']
# ['Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Flour', 'Cheese', 'Flour']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar', 'Sugar']
# ['Juice', 'Tea', 'Juice']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Cheese']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Cheese']
# ['Detergent', 'Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Flour', 'Juice', 'Juice']
# ['Diapers', 'Diapers']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Diapers', 'Diapers']
# ['Tea']
# ['Cheese']
# ['Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Sugar']
# ['Cheese']
# ['Tea']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Sugar', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Diapers', 'Diapers']
# ['Cheese', 'Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Diapers']
# ['Tea']
# ['Detergent', 'Tea', 'Detergent']
# ['Flour', 'Cheese', 'Flour']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Tea']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Diapers', 'Diapers']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Sugar', 'Sugar']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese', 'Detergent']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Tea']
# ['Detergent', 'Tea']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Diapers']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar', 'Diapers']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Tea']
# ['Cheese', 'Cheese']
# ['Flour', 'Juice', 'Juice']
# ['Juice', 'Tea', 'Juice']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Sugar', 'Sugar']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Flour', 'Cheese', 'Flour']
# ['Diapers', 'Diapers']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Flour', 'Juice', 'Juice', 'Flour']
# ['Flour', 'Cheese', 'Flour']
# ['Flour', 'Cheese', 'Flour']
# ['Tea']
# ['Cheese']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Detergent', 'Tea']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Flour', 'Juice', 'Juice']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Sugar', 'Sugar']
# ['Diapers', 'Diapers']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Flour', 'Juice', 'Juice']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Cheese', 'Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Diapers', 'Diapers', 'Diapers']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Cheese', 'Cheese', 'Cheese']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Juice', 'Tea', 'Juice', 'Tea']
# ['Detergent', 'Tea']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Cheese', 'Flour']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Diapers']
# ['Flour', 'Cheese', 'Flour']
# ['Tea']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Cheese']
# ['Sugar', 'Sugar']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Cheese', 'Cheese']
# ['Detergent', 'Tea']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent', 'Detergent']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Cheese']
# ['Detergent', 'Tea']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Flour', 'Cheese', 'Flour']
# ['Cheese']
# ['Tea']
# ['Flour', 'Juice', 'Juice']
# ['Cheese']
# ['Shampoo', 'Detergent', 'Detergent', 'Shampoo']
# ['Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Detergent', 'Tea']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Tea']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Juice', 'Tea', 'Juice']
# ['Flour', 'Cheese', 'Flour', 'Flour']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Tea']
# ['Cheese']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Juice', 'Tea', 'Juice']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Cheese', 'Cheese', 'Cheese']
# ['Tea']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Tea']
# ['Cheese']
# ['Cheese']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Diapers', 'Diapers']
# ['Sugar', 'Sugar']
# ['Flour', 'Juice', 'Juice']
# ['Tea']
# ['Flour', 'Cheese', 'Flour']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Tea']
# ['Diapers', 'Diapers']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo', 'Shampoo']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Tea']
# ['Cheese', 'Cheese']
# ['Cheese']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Flour', 'Cheese', 'Flour', 'Flour']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Tea']
# ['Tea']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Tea']
# ['Cheese', 'Cheese', 'Cheese']
# ['Detergent', 'Tea']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Cheese', 'Cheese']
# ['Detergent', 'Tea']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Cheese', 'Cheese']
# ['Tea']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Sugar', 'Sugar']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Detergent', 'Tea']
# ['Flour', 'Juice', 'Juice']
# ['Cheese', 'Cheese']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Tea']
# ['Diapers', 'Flour', 'Cheese', 'Diapers', 'Cheese']
# ['Cheese', 'Cheese']
# ['Sugar', 'Sugar']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Cheese', 'Cheese']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Shampoo', 'Detergent', 'Detergent']
# ['Flour', 'Juice', 'Juice']
# ['Detergent', 'Tea']
# ['Cheese', 'Cheese']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Diapers', 'Diapers']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Tea']
# ['Tea']
# ['Juice', 'Tea', 'Juice']
# ['Diapers', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Cheese']
# ['Cheese', 'Cheese']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Diapers', 'Flour', 'Cheese', 'Diapers']
# ['Flour', 'Juice', 'Juice']
# ['Sugar', 'Sugar']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Diapers', 'Diapers']
# ['Juice', 'Tea', 'Juice']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Sugar', 'Diapers', 'Cheese', 'Sugar']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Detergent', 'Tea']
# ['Detergent', 'Shampoo', 'Shampoo']
# ['Diapers', 'Diapers']
# ['Flour', 'Cheese', 'Flour']
# ['Cheese', 'Cheese']
# ['Diapers', 'Diapers']
# ['Tea']
# ['Cheese', 'Cheese']
# ['Detergent', 'Cheese', 'Sugar', 'Cheese']
# ['Flour', 'Cheese', 'Flour']
# ['Detergent', 'Shampoo', 'Tea', 'Cheese', 'Shampoo']
# ['Flour', 'Juice', 'Juice']
#
# Generated Association Rules:
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence]
# Index: []
#
#
# Time taken for amazon_data.csv: 0.04 seconds

# %%
from mlxtend.frequent_patterns import fpgrowth, association_rules
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd


def load_transactions(file_path):
    df = pd.read_csv(file_path)
    transactions = df['Filtered Transaction'].apply(lambda x: x.split(', ')).tolist()
    return transactions


def analyze_dataset_with_fpgrowth(file_path, min_support, min_confidence):
    transactions = load_transactions(file_path)
    
    
    te = TransactionEncoder()
    te_ary = te.fit(transactions).transform(transactions)
    df = pd.DataFrame(te_ary, columns=te.columns_)
    
    
    frequent_itemsets = fpgrowth(df, min_support=min_support, use_colnames=True)
    
    
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)
    

    print(f"Frequent Itemsets for {file_path.split('/')[-1]}:")
    print(frequent_itemsets)
    print("\nAssociation Rules:")
    print(rules[['antecedents', 'consequents', 'support', 'confidence']])
    print("\n\n")


def main():
    
    file_paths = [
   'C:\Users\Rushmitha K\Downloads\amazon_data.csv',
    'C:\Users\Rushmitha K\Downloads\costco_data.csv',
    'C:\Users\Rushmitha K\Downloads\best_buy_data.csv',
    'C:\Users\Rushmitha K\Downloads\walgreens_data.csv',
    'C:\Users\Rushmitha K\Downloads\walmart_data.csv'
    ]
    
    
    min_support = float(input("Enter minimum support value (e.g., 0.05 for 5%): "))
    min_confidence = float(input("Enter minimum confidence value (e.g., 0.5 for 50%): "))
    
    
    for file_path in file_paths:
        analyze_dataset_with_fpgrowth(file_path, min_support, min_confidence)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules
import time

def fetch_transactions(csv_path):
    """Loads transactions from a specified CSV file."""
    data = pd.read_csv(csv_path)['Filtered Transaction'].str.split(', ').tolist()
    return data
start_time3 = time.time()
def fp_growth_analysis(csv_path, support_level, confidence_level):
    """Performs FP-Growth analysis on the dataset for given support and confidence levels."""
    transactions = fetch_transactions(csv_path)
    

    encoder = TransactionEncoder()
    encoded_data = encoder.fit(transactions).transform(transactions)
    df_encoded = pd.DataFrame(encoded_data, columns=encoder.columns_)
    
    
    itemsets = fpgrowth(df_encoded, min_support=support_level, use_colnames=True)
    
    
    rules = association_rules(itemsets, metric="confidence", min_threshold=confidence_level)
    
    
    print(f"\nFrequent Itemsets from {csv_path.split('/')[-1]}:")
    print(itemsets)
    print("\nDerived Association Rules:")
    print(rules[['antecedents', 'consequents', 'support', 'confidence']])
    print("\n")

def run_analysis():
    
    dataset_names = ['Amazon', 'Costco', 'Best Buy', 'Walgreens', 'Walmart']
    dataset_paths = { 
       1:'C:\Users\Rushmitha K\Downloads\amazon_data.csv',
        2:'C:\Users\Rushmitha K\Downloads\costco_data.csv',
        3:'C:\Users\Rushmitha K\Downloads\best_buy_data.csv',
        4:'C:\Users\Rushmitha K\Downloads\walgreens_data.csv',
        5:'C:\Users\Rushmitha K\Downloads\walmart_data.csv''

    }

    
    print("Select the dataset(s) to analyze:")
    for i, name in enumerate(dataset_names, 1):
        print(f"{i} - {name}")
    selection = input("Enter the numbers (separated by space) of the datasets to analyze (e.g., 1 3 for Amazon and Best Buy): ")

    selected_indices = selection.split()
    
    
    min_support = float(input("\nEnter minimum support value (e.g., 0.05 for 5%): "))
    min_confidence = float(input("Enter minimum confidence value (e.g., 0.5 for 50%): "))

    
    for index in selected_indices:
        if index.isdigit() and (1 <= int(index) <= len(dataset_paths)):
            fp_growth_analysis(dataset_paths[int(index)-1], min_support, min_confidence)
        else:
            print(f"Invalid selection: {index}")

if __name__ == "__main__":
    run_analysis()
# Out:
# Select the dataset(s) to analyze:
# 1 - Amazon
# 2 - Costco
# 3 - Best Buy
# 4 - Walgreens
# 5 - Walmart
# Enter the numbers (separated by space) of the datasets to analyze (e.g., 1 3 for Amazon and Best Buy):  3
#
# Enter minimum support value (e.g., 0.05 for 5%):  0.05
# Enter minimum confidence value (e.g., 0.5 for 50%):  0.5
# Frequent Itemsets from costco_data.csv:
#      support                                           itemsets
# 0   0.227425                                    ( Bulk Fruits )
# 1   0.109253                                     (Bulk Fruits )
# 2   0.176143                                   ( Optical Items)
# 3   0.054627                                        ( Jewelry )
# 4   0.231884                                    (Bakery Items )
# 5   0.118172                               ( Cleaning Supplies)
# 6   0.118172                                  ( Optical Items )
# 7   0.051282                                     ( Bulk Fruits)
# 8   0.161650                                          ( Tires )
# 9   0.102564                                ( Garden Supplies )
# 10  0.050167                                 (Garden Supplies )
# 11  0.113712                                ( Bulk Vegetables )
# 12  0.052397                               (Cleaning Supplies )
# 13  0.076923                                   ( Bakery Items )
# 14  0.071349                                 ( Bulk Vegetables)
# 15  0.071349                                         (Jewelry )
# 16  0.169454                                 ( Garden Supplies)
# 17  0.101449                                         ( Jewelry)
# 18  0.051282                                          (Jewelry)
# 19  0.057971                     ( Bulk Fruits , Bakery Items )
# 20  0.060201                      ( Bulk Fruits , Bulk Fruits )
# 21  0.050167                            ( Tires , Bulk Fruits )
# 22  0.052397                    ( Bulk Fruits ,  Optical Items)
# 23  0.052397                        ( Optical Items,  Jewelry )
# 24  0.052397                         ( Bulk Fruits ,  Jewelry )
# 25  0.052397         ( Bulk Fruits ,  Optical Items,  Jewelry )
# 26  0.061315                (Bakery Items ,  Cleaning Supplies)
# 27  0.061315              ( Optical Items ,  Cleaning Supplies)
# 28  0.061315                   ( Optical Items , Bakery Items )
# 29  0.056856                   ( Optical Items ,  Bulk Fruits )
# 30  0.061315  ( Optical Items , Bakery Items ,  Cleaning Sup...
# 31  0.051282                      ( Bulk Fruits, Bakery Items )
# 32  0.061315                        ( Garden Supplies,  Tires )
# 33  0.050167                       ( Tires ,  Garden Supplies )
# 34  0.052397             ( Bulk Vegetables ,  Garden Supplies )
# 35  0.050167              (Garden Supplies ,  Garden Supplies )
# 36  0.050167                        (Garden Supplies ,  Tires )
# 37  0.050167     (Garden Supplies ,  Tires ,  Garden Supplies )
# 38  0.061315                       ( Bulk Vegetables ,  Tires )
# 39  0.061315              ( Bulk Vegetables ,  Garden Supplies)
# 40  0.061315     ( Bulk Vegetables ,  Tires ,  Garden Supplies)
# 41  0.052397            (Cleaning Supplies ,  Garden Supplies )
# 42  0.052397            ( Bulk Vegetables , Cleaning Supplies )
# 43  0.052397  ( Bulk Vegetables , Cleaning Supplies ,  Garde...
# 44  0.074693                   ( Optical Items,  Bakery Items )
# 45  0.071349                       ( Bulk Vegetables, Jewelry )
# 46  0.061315                  ( Garden Supplies, Bakery Items )
# 47  0.050167                           ( Jewelry, Bulk Fruits )
# 48  0.050167                                ( Tires ,  Jewelry)
# 49  0.050167                  ( Tires ,  Jewelry, Bulk Fruits )
# 50  0.051282                                (Jewelry,  Jewelry)
#
# Derived Association Rules:
#                                 antecedents  \
# 0                            (Bulk Fruits )
# 1                               ( Jewelry )
# 2                               ( Jewelry )
# 3           ( Bulk Fruits ,  Optical Items)
# 4                ( Bulk Fruits ,  Jewelry )
# 5               ( Optical Items,  Jewelry )
# 6                               ( Jewelry )
# 7                      ( Cleaning Supplies)
# 8                         ( Optical Items )
# 9                      ( Cleaning Supplies)
# 10                        ( Optical Items )
# 11         ( Optical Items , Bakery Items )
# 12    ( Optical Items ,  Cleaning Supplies)
# 13      ( Cleaning Supplies, Bakery Items )
# 14                        ( Optical Items )
# 15                     ( Cleaning Supplies)
# 16                           ( Bulk Fruits)
# 17                      ( Garden Supplies )
# 18                       (Garden Supplies )
# 19                       (Garden Supplies )
# 20              (Garden Supplies ,  Tires )
# 21    (Garden Supplies ,  Garden Supplies )
# 22             ( Tires ,  Garden Supplies )
# 23                       (Garden Supplies )
# 24                      ( Bulk Vegetables )
# 25                      ( Bulk Vegetables )
# 26             ( Bulk Vegetables ,  Tires )
# 27    ( Bulk Vegetables ,  Garden Supplies)
# 28              ( Garden Supplies,  Tires )
# 29                      ( Bulk Vegetables )
# 30                     (Cleaning Supplies )
# 31                      ( Garden Supplies )
# 32                     (Cleaning Supplies )
# 33  ( Bulk Vegetables , Cleaning Supplies )
# 34   ( Bulk Vegetables ,  Garden Supplies )
# 35  (Cleaning Supplies ,  Garden Supplies )
# 36                     (Cleaning Supplies )
# 37                      ( Garden Supplies )
# 38                         ( Bakery Items )
# 39                       ( Bulk Vegetables)
# 40                               (Jewelry )
# 41                      ( Tires ,  Jewelry)
# 42                  ( Tires , Bulk Fruits )
# 43                 ( Jewelry, Bulk Fruits )
# 44                                (Jewelry)
# 45                               ( Jewelry)
#
#                                 consequents   support  confidence
# 0                           ( Bulk Fruits )  0.060201    0.551020
# 1                          ( Optical Items)  0.052397    0.959184
# 2                           ( Bulk Fruits )  0.052397    0.959184
# 3                               ( Jewelry )  0.052397    1.000000
# 4                          ( Optical Items)  0.052397    1.000000
# 5                           ( Bulk Fruits )  0.052397    1.000000
# 6           ( Bulk Fruits ,  Optical Items)  0.052397    0.959184
# 7                           (Bakery Items )  0.061315    0.518868
# 8                      ( Cleaning Supplies)  0.061315    0.518868
# 9                         ( Optical Items )  0.061315    0.518868
# 10                          (Bakery Items )  0.061315    0.518868
# 11                     ( Cleaning Supplies)  0.061315    1.000000
# 12                          (Bakery Items )  0.061315    1.000000
# 13                        ( Optical Items )  0.061315    1.000000
# 14      ( Cleaning Supplies, Bakery Items )  0.061315    0.518868
# 15         ( Optical Items , Bakery Items )  0.061315    0.518868
# 16                          (Bakery Items )  0.051282    1.000000
# 17                      ( Bulk Vegetables )  0.052397    0.510870
# 18                      ( Garden Supplies )  0.050167    1.000000
# 19                                ( Tires )  0.050167    1.000000
# 20                      ( Garden Supplies )  0.050167    1.000000
# 21                                ( Tires )  0.050167    1.000000
# 22                       (Garden Supplies )  0.050167    1.000000
# 23             ( Tires ,  Garden Supplies )  0.050167    1.000000
# 24                                ( Tires )  0.061315    0.539216
# 25                       ( Garden Supplies)  0.061315    0.539216
# 26                       ( Garden Supplies)  0.061315    1.000000
# 27                                ( Tires )  0.061315    1.000000
# 28                      ( Bulk Vegetables )  0.061315    1.000000
# 29              ( Garden Supplies,  Tires )  0.061315    0.539216
# 30                      ( Garden Supplies )  0.052397    1.000000
# 31                     (Cleaning Supplies )  0.052397    0.510870
# 32                      ( Bulk Vegetables )  0.052397    1.000000
# 33                      ( Garden Supplies )  0.052397    1.000000
# 34                     (Cleaning Supplies )  0.052397    1.000000
# 35                      ( Bulk Vegetables )  0.052397    1.000000
# 36   ( Bulk Vegetables ,  Garden Supplies )  0.052397    1.000000
# 37  ( Bulk Vegetables , Cleaning Supplies )  0.052397    0.510870
# 38                         ( Optical Items)  0.074693    0.971014
# 39                               (Jewelry )  0.071349    1.000000
# 40                       ( Bulk Vegetables)  0.071349    1.000000
# 41                           (Bulk Fruits )  0.050167    1.000000
# 42                               ( Jewelry)  0.050167    1.000000
# 43                                ( Tires )  0.050167    1.000000
# 44                               ( Jewelry)  0.051282    1.000000
# 45                                (Jewelry)  0.051282    0.505495
